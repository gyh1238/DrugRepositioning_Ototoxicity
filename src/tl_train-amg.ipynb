# %%
import numpy as np
import torch

#check GPU
print('CUDA available: {}'.format(torch.cuda.is_available()))
print('Current GPU: {}'.format(torch.cuda.get_device_name(torch.cuda.current_device())))
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Out:
# CUDA available: True
# Current GPU: GeForce RTX 2080 SUPER

# %%
import deepchem as dc

loaded, datasets, transformers = dc.utils.load_dataset_from_disk('data/combined/amg')
train_dataset, valid_dataset, test_dataset = datasets
print('train/val/test split: {}/{}/{}'.format(
    len(train_dataset), len(valid_dataset), len(test_dataset)))
# Out:
# train/val/test split: 483/60/61

# %%
num_node_features = train_dataset.X[0].num_node_features
num_edge_features = train_dataset.X[0].num_edge_features
num_classes = train_dataset.y[0].shape[-1]
print(num_node_features, num_classes)
# Out:
# 79 1

# %%
from torch_geometric.data import Data, DataLoader

def get_data_loader(dc_dataset, batch_size=64, shuffle=True):
    ds = [x.to_pyg_graph() for x in dc_dataset.X]
    for i in range(len(ds)):
        ds[i].y = torch.from_numpy(dc_dataset.y[i].reshape(1, -1))
        ds[i].w = torch.from_numpy(dc_dataset.w[i].reshape(1, -1))
    return DataLoader(ds, batch_size=batch_size, shuffle=shuffle)

train_loader = get_data_loader(train_dataset, batch_size=64, shuffle=True)
val_loader = get_data_loader(valid_dataset, batch_size=64, shuffle=True)
test_loader = get_data_loader(test_dataset, batch_size=64, shuffle=True)

for step, data in enumerate(train_loader):
    print('Step {}:'.format(step + 1))
    print('=======')
    print('Number of graphs in the current batch: {}'.format(data.num_graphs))
    print(data, '\n')
# Out:
# RDKit WARNING: [02:10:21] Enabling RDKit 2019.09.3 jupyter extensions
# Step 1:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1484], edge_attr=[3200, 12], edge_index=[2, 3200], ptr=[65], w=[64, 1], x=[1484, 79], y=[64, 1])
#
# Step 2:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1330], edge_attr=[2860, 12], edge_index=[2, 2860], ptr=[65], w=[64, 1], x=[1330, 79], y=[64, 1])
#
# Step 3:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1414], edge_attr=[3040, 12], edge_index=[2, 3040], ptr=[65], w=[64, 1], x=[1414, 79], y=[64, 1])
#
# Step 4:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1255], edge_attr=[2698, 12], edge_index=[2, 2698], ptr=[65], w=[64, 1], x=[1255, 79], y=[64, 1])
#
# Step 5:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1599], edge_attr=[3432, 12], edge_index=[2, 3432], ptr=[65], w=[64, 1], x=[1599, 79], y=[64, 1])
#
# Step 6:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1515], edge_attr=[3246, 12], edge_index=[2, 3246], ptr=[65], w=[64, 1], x=[1515, 79], y=[64, 1])
#
# Step 7:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1390], edge_attr=[3020, 12], edge_index=[2, 3020], ptr=[65], w=[64, 1], x=[1390, 79], y=[64, 1])
#
# Step 8:
# =======
# Number of graphs in the current batch: 35
# Batch(batch=[918], edge_attr=[1966, 12], edge_index=[2, 1966], ptr=[36], w=[35, 1], x=[918, 79], y=[35, 1])

# %%
from sklearn.metrics import roc_auc_score, average_precision_score
from sklearn.metrics import precision_score, recall_score

def train(model, optimizer, criterion):
    model.train()

    for data in train_loader:  # Iterate in batches over the training dataset.
        data = data.to(device)
        
        out = model(data.x, data.edge_index, data.edge_attr, data.batch)
        
        #loss = criterion(out, data.y)
        loss = criterion(out, data.y, weights=data.w)
        
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

def test(model, loader):
    model.eval()

    outs = []
    ys = []
    for data in loader:  # Iterate in batches over the training/test dataset.
        data = data.to(device)
        
        #out = model(data.x, data.edge_index, data.batch)  # Perform a single forward pass.
        out = model(data.x, data.edge_index, data.edge_attr, data.batch)
        
        outs.append(out.detach().cpu().numpy())
        ys.append(data.y.detach().cpu().numpy())
    
    pred = np.concatenate(outs, axis=0)
    y = np.concatenate(ys, axis=0)
    
    roc_auc = roc_auc_score(y, pred)
    ave_prec = average_precision_score(y, pred)
    return roc_auc, ave_prec

def test_precision_recall(model, loader, pred_th=0.5):
    model.eval()

    outs = []
    ys = []
    for data in loader:  # Iterate in batches over the training/test dataset.
        data = data.to(device)
        
        out = model(data.x, data.edge_index, 
                     data.edge_attr, data.batch)
        
        outs.append(out.detach().cpu().numpy())
        ys.append(data.y.detach().cpu().numpy())
    
    pred = np.concatenate(outs, axis=0)
    y = np.concatenate(ys, axis=0).astype(int)
    binary_pred = (pred > pred_th).astype(int)
    
    precision = precision_score(y, binary_pred, zero_division=0)
    recall = recall_score(y, binary_pred, zero_division=0)
    return precision, recall

def get_loss(model, loader):
    model.eval()

    losses = []
    for data in loader:
        data = data.to(device)
        out = model(data.x, data.edge_index, data.edge_attr, data.batch)
        loss = criterion(out, data.y, data.w)
        losses.append(loss.detach().cpu().numpy())
    return np.mean(losses)

# %%
from models import AttentiveFP

model = AttentiveFP(in_channels=num_node_features, hidden_channels=512, 
                    out_channels=num_classes, edge_dim=num_edge_features, 
                    num_layers=4, num_timesteps=3,
                    dropout=0.4).to(device)
print(model)
# Out:
# AttentiveFP(
#   (lin1): Linear(in_features=79, out_features=512, bias=True)
#   (atom_convs): ModuleList(
#     (0): GATEConv(
#       (lin1): Linear(in_features=524, out_features=512, bias=False)
#       (lin2): Linear(in_features=512, out_features=512, bias=False)
#     )
#     (1): GATConv(512, 512, heads=1)
#     (2): GATConv(512, 512, heads=1)
#     (3): GATConv(512, 512, heads=1)
#   )
#   (atom_grus): ModuleList(
#     (0): GRUCell(512, 512)
#     (1): GRUCell(512, 512)
#     (2): GRUCell(512, 512)
#     (3): GRUCell(512, 512)
#   )
#   (atom_norms): ModuleList(
#     (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     (2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     (3): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   )
#   (mol_conv): GATConv(512, 512, heads=1)
#   (mol_gru): GRUCell(512, 512)
#   (lin2): Linear(in_features=512, out_features=1, bias=True)
# )

# %%
#transfer learning step

model_state_dict = model.state_dict()

pretrained_model = torch.load('pretrained_models/AFP_0.72710')
#pretrained_model = torch.load('pretrained_models/AFP_0.71991')
pretrained_state_dict = pretrained_model.state_dict()
sel_pretrained_state_dict = {k: v for k, v in pretrained_state_dict.items() 
                             if model_state_dict[k].size() == v.size()}
model_state_dict.update(sel_pretrained_state_dict) 
model.load_state_dict(model_state_dict)
# Out:
# <All keys matched successfully>

# %%
for p in model.parameters():
    p.requires_grad = False
for p in model.lin2.parameters():
    p.requires_grad = True

# %%
from loss import PrecisionAtRecallLoss, PrecisionRecallAUCLoss, PrecisionRecallAUCLoss2

#optimizer = torch.optim.Adam(model.parameters(), lr=3e-5)
optimizer = torch.optim.RMSprop(model.parameters(), lr=1e-4)
#criterion = torch.nn.BCEWithLogitsLoss(reduction='none')
#criterion = RecallAtPrecisionLoss(num_classes=num_classes, target_precision=0.9).to(device)
#criterion = PrecisionAtRecallLoss(num_classes=num_classes, target_recall=0.5).to(device)
#criterion = PrecisionAtRecallLoss(
#    num_classes=num_classes, target_recall=0.1, surrogate_type='hinge').to(device)
#criterion = PrecisionRecallAUCLoss(
#    num_classes=num_classes, precision_range=(0.0, 0.5)).to(device)
criterion = PrecisionRecallAUCLoss2(
    num_classes=num_classes, recall_range=(0.0, 1.0)).to(device)


for epoch in range(1, 31):
    train(model, optimizer, criterion)
    tr_loss = get_loss(model, train_loader)
    val_loss = get_loss(model, val_loader)
    print('Epoch: {:03d}, Train loss: {:.5f}, Val loss: {:.5f}'.format(
        epoch, tr_loss, val_loss))
    
    tr_roc_auc, tr_ave_prec = test(model, train_loader)
    val_roc_auc, val_ave_prec  = test(model, val_loader)
    print('Train - roc_auc:{:.4f}, ave_prec:{:.4f}, Val - roc_auc:{:.4f}, ave_prec:{:.4f}'.format(
        tr_roc_auc, tr_ave_prec, val_roc_auc, val_ave_prec))
    
    tr_precision, tr_recall = test_precision_recall(model, train_loader)
    val_precision, val_recall  = test_precision_recall(model, val_loader)
    print('Train - precision:{:.4f}, recall:{:.4f}, Val - precision:{:.4f}, recall:{:.4f}'.format(
        tr_precision, tr_recall, val_precision, val_recall))
    
te_loss  = get_loss(model, test_loader)
print('Test loss: {:.5f}'.format(te_loss))
te_roc_auc, te_ave_prec = test(model, test_loader)
print('Test - roc_auc:{:.4f}, ave_prec:{:.4f}'.format(te_roc_auc, te_ave_prec))
te_precision, te_recall = test_precision_recall(model, test_loader)
print('Test - precision:{:.4f}, recall:{:.4f}'.format(te_precision, te_recall))
# Out:
# Epoch: 001, Train loss: 1.21446, Val loss: 1.09994
# Train - roc_auc:0.7037, ave_prec:0.2062, Val - roc_auc:0.8895, ave_prec:0.5831
# Train - precision:0.1000, recall:0.0185, Val - precision:0.0000, recall:0.0000
# Epoch: 002, Train loss: 1.11450, Val loss: 1.06081
# Train - roc_auc:0.7460, ave_prec:0.2268, Val - roc_auc:0.9353, ave_prec:0.6560
# Train - precision:0.2083, recall:0.0926, Val - precision:0.5000, recall:0.1429
# Epoch: 003, Train loss: 1.10612, Val loss: 1.02447
# Train - roc_auc:0.7695, ave_prec:0.2406, Val - roc_auc:0.9488, ave_prec:0.6669
# Train - precision:0.2292, recall:0.2037, Val - precision:0.7500, recall:0.4286
# Epoch: 004, Train loss: 1.10180, Val loss: 1.00316
# Train - roc_auc:0.7789, ave_prec:0.2481, Val - roc_auc:0.9515, ave_prec:0.6561
# Train - precision:0.3158, recall:0.3333, Val - precision:0.7500, recall:0.4286
# Epoch: 005, Train loss: 1.06779, Val loss: 0.98100
# Train - roc_auc:0.7851, ave_prec:0.2523, Val - roc_auc:0.9488, ave_prec:0.6235
# Train - precision:0.2933, recall:0.4074, Val - precision:0.5455, recall:0.8571
# Epoch: 006, Train loss: 1.04961, Val loss: 0.96213
# Train - roc_auc:0.7881, ave_prec:0.2567, Val - roc_auc:0.9515, ave_prec:0.6917
# Train - precision:0.2963, recall:0.4444, Val - precision:0.5455, recall:0.8571
# Epoch: 007, Train loss: 1.05021, Val loss: 0.94879
# Train - roc_auc:0.7909, ave_prec:0.2593, Val - roc_auc:0.9515, ave_prec:0.6869
# Train - precision:0.2892, recall:0.4444, Val - precision:0.5455, recall:0.8571
# Epoch: 008, Train loss: 1.04020, Val loss: 0.93756
# Train - roc_auc:0.7923, ave_prec:0.2597, Val - roc_auc:0.9542, ave_prec:0.6964
# Train - precision:0.2976, recall:0.4630, Val - precision:0.5455, recall:0.8571
# Epoch: 009, Train loss: 1.03051, Val loss: 0.92736
# Train - roc_auc:0.7941, ave_prec:0.2607, Val - roc_auc:0.9542, ave_prec:0.6924
# Train - precision:0.3059, recall:0.4815, Val - precision:0.5455, recall:0.8571
# Epoch: 010, Train loss: 1.01942, Val loss: 0.91975
# Train - roc_auc:0.7950, ave_prec:0.2612, Val - roc_auc:0.9569, ave_prec:0.7019
# Train - precision:0.2989, recall:0.4815, Val - precision:0.5455, recall:0.8571
# Epoch: 011, Train loss: 1.04955, Val loss: 0.90841
# Train - roc_auc:0.7969, ave_prec:0.2633, Val - roc_auc:0.9569, ave_prec:0.7019
# Train - precision:0.2967, recall:0.5000, Val - precision:0.5455, recall:0.8571
# Epoch: 012, Train loss: 1.01273, Val loss: 0.89935
# Train - roc_auc:0.7979, ave_prec:0.2664, Val - roc_auc:0.9569, ave_prec:0.6988
# Train - precision:0.2784, recall:0.5000, Val - precision:0.5455, recall:0.8571
# Epoch: 013, Train loss: 1.00855, Val loss: 0.88964
# Train - roc_auc:0.7982, ave_prec:0.2698, Val - roc_auc:0.9569, ave_prec:0.6988
# Train - precision:0.2727, recall:0.5000, Val - precision:0.5833, recall:1.0000
# Epoch: 014, Train loss: 1.02290, Val loss: 0.88237
# Train - roc_auc:0.7990, ave_prec:0.2710, Val - roc_auc:0.9569, ave_prec:0.6988
# Train - precision:0.2755, recall:0.5000, Val - precision:0.5833, recall:1.0000
# Epoch: 015, Train loss: 1.00134, Val loss: 0.87346
# Train - roc_auc:0.7995, ave_prec:0.2715, Val - roc_auc:0.9569, ave_prec:0.6988
# Train - precision:0.2772, recall:0.5185, Val - precision:0.5833, recall:1.0000
# Epoch: 016, Train loss: 1.01350, Val loss: 0.86333
# Train - roc_auc:0.8007, ave_prec:0.2789, Val - roc_auc:0.9515, ave_prec:0.6696
# Train - precision:0.2830, recall:0.5556, Val - precision:0.5385, recall:1.0000
# Epoch: 017, Train loss: 0.98336, Val loss: 0.85703
# Train - roc_auc:0.8013, ave_prec:0.2797, Val - roc_auc:0.9542, ave_prec:0.6774
# Train - precision:0.2718, recall:0.5185, Val - precision:0.5385, recall:1.0000
# Epoch: 018, Train loss: 0.99550, Val loss: 0.85353
# Train - roc_auc:0.8023, ave_prec:0.2812, Val - roc_auc:0.9542, ave_prec:0.6774
# Train - precision:0.2673, recall:0.5000, Val - precision:0.5385, recall:1.0000
# Epoch: 019, Train loss: 1.00745, Val loss: 0.84824
# Train - roc_auc:0.8029, ave_prec:0.2823, Val - roc_auc:0.9542, ave_prec:0.6774
# Train - precision:0.2700, recall:0.5000, Val - precision:0.5833, recall:1.0000
# Epoch: 020, Train loss: 0.99102, Val loss: 0.84216
# Train - roc_auc:0.8031, ave_prec:0.2825, Val - roc_auc:0.9569, ave_prec:0.6850
# Train - precision:0.2755, recall:0.5000, Val - precision:0.5833, recall:1.0000
# Epoch: 021, Train loss: 0.99456, Val loss: 0.83626
# Train - roc_auc:0.8043, ave_prec:0.2843, Val - roc_auc:0.9596, ave_prec:0.6945
# Train - precision:0.2745, recall:0.5185, Val - precision:0.5385, recall:1.0000
# Epoch: 022, Train loss: 0.97271, Val loss: 0.82994
# Train - roc_auc:0.8052, ave_prec:0.2853, Val - roc_auc:0.9596, ave_prec:0.6945
# Train - precision:0.2745, recall:0.5185, Val - precision:0.5385, recall:1.0000
# Epoch: 023, Train loss: 0.98259, Val loss: 0.82798
# Train - roc_auc:0.8061, ave_prec:0.2868, Val - roc_auc:0.9596, ave_prec:0.6945
# Train - precision:0.2772, recall:0.5185, Val - precision:0.5385, recall:1.0000
# Epoch: 024, Train loss: 0.96626, Val loss: 0.82112
# Train - roc_auc:0.8062, ave_prec:0.2873, Val - roc_auc:0.9623, ave_prec:0.7036
# Train - precision:0.2745, recall:0.5185, Val - precision:0.5385, recall:1.0000
# Epoch: 025, Train loss: 0.96762, Val loss: 0.81669
# Train - roc_auc:0.8069, ave_prec:0.2888, Val - roc_auc:0.9623, ave_prec:0.7036
# Train - precision:0.2745, recall:0.5185, Val - precision:0.5385, recall:1.0000
# Epoch: 026, Train loss: 0.97342, Val loss: 0.81357
# Train - roc_auc:0.8073, ave_prec:0.2896, Val - roc_auc:0.9623, ave_prec:0.7036
# Train - precision:0.2772, recall:0.5185, Val - precision:0.5385, recall:1.0000
# Epoch: 027, Train loss: 0.97246, Val loss: 0.81099
# Train - roc_auc:0.8082, ave_prec:0.2910, Val - roc_auc:0.9623, ave_prec:0.7036
# Train - precision:0.2772, recall:0.5185, Val - precision:0.5385, recall:1.0000
# Epoch: 028, Train loss: 0.98201, Val loss: 0.80626
# Train - roc_auc:0.8089, ave_prec:0.2934, Val - roc_auc:0.9623, ave_prec:0.7036
# Train - precision:0.2772, recall:0.5185, Val - precision:0.5385, recall:1.0000
# Epoch: 029, Train loss: 0.97302, Val loss: 0.80321
# Train - roc_auc:0.8096, ave_prec:0.2941, Val - roc_auc:0.9623, ave_prec:0.7036
# Train - precision:0.2913, recall:0.5556, Val - precision:0.5385, recall:1.0000
# Epoch: 030, Train loss: 0.95671, Val loss: 0.80000
# Train - roc_auc:0.8101, ave_prec:0.2952, Val - roc_auc:0.9623, ave_prec:0.7036
# Train - precision:0.2843, recall:0.5370, Val - precision:0.5385, recall:1.0000
# Test loss: 0.91932
# Test - roc_auc:0.8915, ave_prec:0.4352
# Test - precision:0.5000, recall:0.7143

# %%
tr_precision, tr_recall = test_precision_recall(model, train_loader, pred_th=0.8)
val_precision, val_recall  = test_precision_recall(model, val_loader, pred_th=0.8)
print('Train - precision:{:.4f}, recall:{:.4f}, Val - precision:{:.4f}, recall:{:.4f}'.format(
    tr_precision, tr_recall, val_precision, val_recall))
te_precision, te_recall = test_precision_recall(model, test_loader, pred_th=0.8)
print('Test - precision:{:.4f}, recall:{:.4f}'.format(te_precision, te_recall))
# Out:
# Train - precision:0.3387, recall:0.3889, Val - precision:0.5000, recall:0.2857
# Test - precision:0.4000, recall:0.2857

# %%
for p in model.parameters():
    p.requires_grad = True

# %%
optimizer = torch.optim.RMSprop(model.parameters(), lr=3e-6)
#criterion = torch.nn.BCEWithLogitsLoss(reduction='none')
#criterion = RecallAtPrecisionLoss(num_classes=num_classes, target_precision=0.99).to(device)
#criterion = PrecisionAtRecallLoss(num_classes=num_classes, target_recall=0.05).to(device)
#criterion = PrecisionAtRecallLoss(
#    num_classes=num_classes, target_recall=0.1, surrogate_type='hinge').to(device)
#criterion = PrecisionRecallAUCLoss(
#    num_classes=num_classes, precision_range=(0.5, 1.)).to(device)
criterion = PrecisionRecallAUCLoss2(
    num_classes=num_classes, recall_range=(0.0, 1.0)).to(device)


for epoch in range(1, 101):
    train(model, optimizer, criterion)
    tr_loss = get_loss(model, train_loader)
    val_loss = get_loss(model, val_loader)
    print('Epoch: {:03d}, Train loss: {:.5f}, Val loss: {:.5f}'.format(
        epoch, tr_loss, val_loss))
    
    tr_roc_auc, tr_ave_prec = test(model, train_loader)
    val_roc_auc, val_ave_prec  = test(model, val_loader)
    print('Train - roc_auc:{:.4f}, ave_prec:{:.4f}, Val - roc_auc:{:.4f}, ave_prec:{:.4f}'.format(
        tr_roc_auc, tr_ave_prec, val_roc_auc, val_ave_prec))
    
    tr_precision, tr_recall = test_precision_recall(model, train_loader)
    val_precision, val_recall  = test_precision_recall(model, val_loader)
    print('Train - precision:{:.4f}, recall:{:.4f}, Val - precision:{:.4f}, recall:{:.4f}'.format(
        tr_precision, tr_recall, val_precision, val_recall))
    
te_loss  = get_loss(model, test_loader)
print('Test loss: {:.5f}'.format(te_loss))
te_roc_auc, te_ave_prec = test(model, test_loader)
print('Test - roc_auc:{:.4f}, ave_prec:{:.4f}'.format(te_roc_auc, te_ave_prec))
te_precision, te_recall = test_precision_recall(model, test_loader)
print('Test - precision:{:.4f}, recall:{:.4f}'.format(te_precision, te_recall))
# Out:
# Epoch: 001, Train loss: 0.89846, Val loss: 0.74855
# Train - roc_auc:0.8248, ave_prec:0.3139, Val - roc_auc:0.9650, ave_prec:0.7512
# Train - precision:0.3053, recall:0.5370, Val - precision:0.5833, recall:1.0000
# Epoch: 002, Train loss: 0.89706, Val loss: 0.72863
# Train - roc_auc:0.8369, ave_prec:0.3379, Val - roc_auc:0.9677, ave_prec:0.7639
# Train - precision:0.3200, recall:0.5926, Val - precision:0.5833, recall:1.0000
# Epoch: 003, Train loss: 0.87955, Val loss: 0.71016
# Train - roc_auc:0.8424, ave_prec:0.3564, Val - roc_auc:0.9704, ave_prec:0.7854
# Train - precision:0.3232, recall:0.5926, Val - precision:0.5833, recall:1.0000
# Epoch: 004, Train loss: 0.87211, Val loss: 0.70264
# Train - roc_auc:0.8468, ave_prec:0.3647, Val - roc_auc:0.9704, ave_prec:0.7854
# Train - precision:0.3173, recall:0.6111, Val - precision:0.5833, recall:1.0000
# Epoch: 005, Train loss: 0.88644, Val loss: 0.68930
# Train - roc_auc:0.8485, ave_prec:0.3730, Val - roc_auc:0.9704, ave_prec:0.7854
# Train - precision:0.3300, recall:0.6111, Val - precision:0.5833, recall:1.0000
# Epoch: 006, Train loss: 0.83748, Val loss: 0.67438
# Train - roc_auc:0.8506, ave_prec:0.3829, Val - roc_auc:0.9704, ave_prec:0.7854
# Train - precision:0.3511, recall:0.6111, Val - precision:0.6364, recall:1.0000
# Epoch: 007, Train loss: 0.82890, Val loss: 0.67204
# Train - roc_auc:0.8547, ave_prec:0.3993, Val - roc_auc:0.9730, ave_prec:0.8211
# Train - precision:0.3511, recall:0.6111, Val - precision:0.6364, recall:1.0000
# Epoch: 008, Train loss: 0.82696, Val loss: 0.65973
# Train - roc_auc:0.8586, ave_prec:0.4172, Val - roc_auc:0.9730, ave_prec:0.8211
# Train - precision:0.3516, recall:0.5926, Val - precision:0.7000, recall:1.0000
# Epoch: 009, Train loss: 0.82646, Val loss: 0.65422
# Train - roc_auc:0.8617, ave_prec:0.4290, Val - roc_auc:0.9730, ave_prec:0.8211
# Train - precision:0.3548, recall:0.6111, Val - precision:0.7000, recall:1.0000
# Epoch: 010, Train loss: 0.85989, Val loss: 0.64258
# Train - roc_auc:0.8650, ave_prec:0.4356, Val - roc_auc:0.9730, ave_prec:0.8211
# Train - precision:0.3556, recall:0.5926, Val - precision:0.7000, recall:1.0000
# Epoch: 011, Train loss: 0.81279, Val loss: 0.63586
# Train - roc_auc:0.8682, ave_prec:0.4400, Val - roc_auc:0.9730, ave_prec:0.8211
# Train - precision:0.3587, recall:0.6111, Val - precision:0.7000, recall:1.0000
# Epoch: 012, Train loss: 0.80618, Val loss: 0.63950
# Train - roc_auc:0.8706, ave_prec:0.4410, Val - roc_auc:0.9757, ave_prec:0.8330
# Train - precision:0.3711, recall:0.6667, Val - precision:0.6364, recall:1.0000
# Epoch: 013, Train loss: 0.78645, Val loss: 0.63129
# Train - roc_auc:0.8728, ave_prec:0.4449, Val - roc_auc:0.9757, ave_prec:0.8330
# Train - precision:0.3776, recall:0.6852, Val - precision:0.6364, recall:1.0000
# Epoch: 014, Train loss: 0.79559, Val loss: 0.61946
# Train - roc_auc:0.8746, ave_prec:0.4510, Val - roc_auc:0.9757, ave_prec:0.8330
# Train - precision:0.3895, recall:0.6852, Val - precision:0.7000, recall:1.0000
# Epoch: 015, Train loss: 0.77634, Val loss: 0.61583
# Train - roc_auc:0.8768, ave_prec:0.4481, Val - roc_auc:0.9784, ave_prec:0.8520
# Train - precision:0.3814, recall:0.6852, Val - precision:0.6364, recall:1.0000
# Epoch: 016, Train loss: 0.77133, Val loss: 0.60382
# Train - roc_auc:0.8783, ave_prec:0.4530, Val - roc_auc:0.9784, ave_prec:0.8520
# Train - precision:0.3895, recall:0.6852, Val - precision:0.7000, recall:1.0000
# Epoch: 017, Train loss: 0.77415, Val loss: 0.60404
# Train - roc_auc:0.8800, ave_prec:0.4548, Val - roc_auc:0.9784, ave_prec:0.8520
# Train - precision:0.3814, recall:0.6852, Val - precision:0.6364, recall:1.0000
# Epoch: 018, Train loss: 0.76454, Val loss: 0.59311
# Train - roc_auc:0.8804, ave_prec:0.4568, Val - roc_auc:0.9784, ave_prec:0.8520
# Train - precision:0.3978, recall:0.6852, Val - precision:0.7000, recall:1.0000
# Epoch: 019, Train loss: 0.76071, Val loss: 0.59212
# Train - roc_auc:0.8812, ave_prec:0.4468, Val - roc_auc:0.9784, ave_prec:0.8520
# Train - precision:0.3978, recall:0.6852, Val - precision:0.7000, recall:1.0000
# Epoch: 020, Train loss: 0.74825, Val loss: 0.58606
# Train - roc_auc:0.8836, ave_prec:0.4518, Val - roc_auc:0.9784, ave_prec:0.8520
# Train - precision:0.3978, recall:0.6852, Val - precision:0.7000, recall:1.0000
# Epoch: 021, Train loss: 0.74320, Val loss: 0.58309
# Train - roc_auc:0.8851, ave_prec:0.4534, Val - roc_auc:0.9784, ave_prec:0.8520
# Train - precision:0.3936, recall:0.6852, Val - precision:0.6364, recall:1.0000
# Epoch: 022, Train loss: 0.73819, Val loss: 0.57996
# Train - roc_auc:0.8869, ave_prec:0.4594, Val - roc_auc:0.9784, ave_prec:0.8520
# Train - precision:0.4000, recall:0.7037, Val - precision:0.7000, recall:1.0000
# Epoch: 023, Train loss: 0.74473, Val loss: 0.57210
# Train - roc_auc:0.8885, ave_prec:0.4640, Val - roc_auc:0.9784, ave_prec:0.8520
# Train - precision:0.3958, recall:0.7037, Val - precision:0.7000, recall:1.0000
# Epoch: 024, Train loss: 0.72633, Val loss: 0.56851
# Train - roc_auc:0.8894, ave_prec:0.4598, Val - roc_auc:0.9784, ave_prec:0.8520
# Train - precision:0.4021, recall:0.7222, Val - precision:0.7000, recall:1.0000
# Epoch: 025, Train loss: 0.72478, Val loss: 0.55979
# Train - roc_auc:0.8910, ave_prec:0.4643, Val - roc_auc:0.9811, ave_prec:0.8690
# Train - precision:0.3958, recall:0.7037, Val - precision:0.7000, recall:1.0000
# Epoch: 026, Train loss: 0.71169, Val loss: 0.56190
# Train - roc_auc:0.8927, ave_prec:0.4781, Val - roc_auc:0.9784, ave_prec:0.8520
# Train - precision:0.4040, recall:0.7407, Val - precision:0.6364, recall:1.0000
# Epoch: 027, Train loss: 0.70405, Val loss: 0.55487
# Train - roc_auc:0.8935, ave_prec:0.4781, Val - roc_auc:0.9811, ave_prec:0.8690
# Train - precision:0.3958, recall:0.7037, Val - precision:0.6667, recall:0.8571
# Epoch: 028, Train loss: 0.71411, Val loss: 0.55445
# Train - roc_auc:0.8955, ave_prec:0.4893, Val - roc_auc:0.9811, ave_prec:0.8690
# Train - precision:0.4040, recall:0.7407, Val - precision:0.7000, recall:1.0000
# Epoch: 029, Train loss: 0.71096, Val loss: 0.54916
# Train - roc_auc:0.8951, ave_prec:0.4828, Val - roc_auc:0.9811, ave_prec:0.8690
# Train - precision:0.4105, recall:0.7222, Val - precision:0.6667, recall:0.8571
# Epoch: 030, Train loss: 0.70270, Val loss: 0.54994
# Train - roc_auc:0.8965, ave_prec:0.4875, Val - roc_auc:0.9784, ave_prec:0.8600
# Train - precision:0.4021, recall:0.7222, Val - precision:0.6000, recall:0.8571
# Epoch: 031, Train loss: 0.73140, Val loss: 0.54136
# Train - roc_auc:0.8973, ave_prec:0.4937, Val - roc_auc:0.9811, ave_prec:0.8690
# Train - precision:0.4043, recall:0.7037, Val - precision:0.6667, recall:0.8571
# Epoch: 032, Train loss: 0.68767, Val loss: 0.54239
# Train - roc_auc:0.8978, ave_prec:0.4930, Val - roc_auc:0.9811, ave_prec:0.8806
# Train - precision:0.4021, recall:0.7222, Val - precision:0.6667, recall:0.8571
# Epoch: 033, Train loss: 0.68966, Val loss: 0.54009
# Train - roc_auc:0.8991, ave_prec:0.4913, Val - roc_auc:0.9784, ave_prec:0.8520
# Train - precision:0.4062, recall:0.7222, Val - precision:0.6667, recall:0.8571
# Epoch: 034, Train loss: 0.68945, Val loss: 0.53478
# Train - roc_auc:0.9000, ave_prec:0.4946, Val - roc_auc:0.9811, ave_prec:0.8806
# Train - precision:0.4062, recall:0.7222, Val - precision:0.6667, recall:0.8571
# Epoch: 035, Train loss: 0.68689, Val loss: 0.53959
# Train - roc_auc:0.9024, ave_prec:0.5090, Val - roc_auc:0.9784, ave_prec:0.8715
# Train - precision:0.4078, recall:0.7778, Val - precision:0.6000, recall:0.8571
# Epoch: 036, Train loss: 0.68777, Val loss: 0.53114
# Train - roc_auc:0.9033, ave_prec:0.5053, Val - roc_auc:0.9811, ave_prec:0.8806
# Train - precision:0.4040, recall:0.7407, Val - precision:0.6667, recall:0.8571
# Epoch: 037, Train loss: 0.68452, Val loss: 0.52631
# Train - roc_auc:0.9042, ave_prec:0.5072, Val - roc_auc:0.9811, ave_prec:0.8806
# Train - precision:0.4040, recall:0.7407, Val - precision:0.6667, recall:0.8571
# Epoch: 038, Train loss: 0.68195, Val loss: 0.52614
# Train - roc_auc:0.9053, ave_prec:0.5120, Val - roc_auc:0.9811, ave_prec:0.8806
# Train - precision:0.4082, recall:0.7407, Val - precision:0.6667, recall:0.8571
# Epoch: 039, Train loss: 0.66855, Val loss: 0.52275
# Train - roc_auc:0.9056, ave_prec:0.5118, Val - roc_auc:0.9811, ave_prec:0.8806
# Train - precision:0.4167, recall:0.7407, Val - precision:0.6667, recall:0.8571
# Epoch: 040, Train loss: 0.66535, Val loss: 0.51575
# Train - roc_auc:0.9059, ave_prec:0.5101, Val - roc_auc:0.9811, ave_prec:0.8806
# Train - precision:0.4167, recall:0.7407, Val - precision:0.6667, recall:0.8571
# Epoch: 041, Train loss: 0.66125, Val loss: 0.51131
# Train - roc_auc:0.9075, ave_prec:0.5172, Val - roc_auc:0.9811, ave_prec:0.8806
# Train - precision:0.4149, recall:0.7222, Val - precision:0.6667, recall:0.8571
# Epoch: 042, Train loss: 0.67496, Val loss: 0.50425
# Train - roc_auc:0.9090, ave_prec:0.5129, Val - roc_auc:0.9811, ave_prec:0.8806
# Train - precision:0.4211, recall:0.7407, Val - precision:0.6667, recall:0.8571
# Epoch: 043, Train loss: 0.65283, Val loss: 0.50957
# Train - roc_auc:0.9104, ave_prec:0.5224, Val - roc_auc:0.9811, ave_prec:0.8806
# Train - precision:0.4272, recall:0.8148, Val - precision:0.6667, recall:0.8571
# Epoch: 044, Train loss: 0.64932, Val loss: 0.50153
# Train - roc_auc:0.9101, ave_prec:0.5162, Val - roc_auc:0.9811, ave_prec:0.8806
# Train - precision:0.4343, recall:0.7963, Val - precision:0.6667, recall:0.8571
# Epoch: 045, Train loss: 0.65056, Val loss: 0.50115
# Train - roc_auc:0.9112, ave_prec:0.5167, Val - roc_auc:0.9811, ave_prec:0.8806
# Train - precision:0.4433, recall:0.7963, Val - precision:0.6667, recall:0.8571
# Epoch: 046, Train loss: 0.63836, Val loss: 0.49654
# Train - roc_auc:0.9128, ave_prec:0.5199, Val - roc_auc:0.9811, ave_prec:0.8806
# Train - precision:0.4375, recall:0.7778, Val - precision:0.6667, recall:0.8571
# Epoch: 047, Train loss: 0.64644, Val loss: 0.49281
# Train - roc_auc:0.9136, ave_prec:0.5226, Val - roc_auc:0.9811, ave_prec:0.8806
# Train - precision:0.4421, recall:0.7778, Val - precision:0.6667, recall:0.8571
# Epoch: 048, Train loss: 0.65655, Val loss: 0.48692
# Train - roc_auc:0.9144, ave_prec:0.5273, Val - roc_auc:0.9811, ave_prec:0.8806
# Train - precision:0.4457, recall:0.7593, Val - precision:0.6667, recall:0.8571
# Epoch: 049, Train loss: 0.63313, Val loss: 0.48486
# Train - roc_auc:0.9151, ave_prec:0.5288, Val - roc_auc:0.9811, ave_prec:0.8806
# Train - precision:0.4505, recall:0.7593, Val - precision:0.6667, recall:0.8571
# Epoch: 050, Train loss: 0.62166, Val loss: 0.48196
# Train - roc_auc:0.9167, ave_prec:0.5349, Val - roc_auc:0.9811, ave_prec:0.8806
# Train - precision:0.4457, recall:0.7593, Val - precision:0.6667, recall:0.8571
# Epoch: 051, Train loss: 0.61746, Val loss: 0.47616
# Train - roc_auc:0.9178, ave_prec:0.5345, Val - roc_auc:0.9865, ave_prec:0.9129
# Train - precision:0.4444, recall:0.7407, Val - precision:0.6667, recall:0.8571
# Epoch: 052, Train loss: 0.63064, Val loss: 0.47911
# Train - roc_auc:0.9182, ave_prec:0.5366, Val - roc_auc:0.9811, ave_prec:0.8806
# Train - precision:0.4574, recall:0.7963, Val - precision:0.6667, recall:0.8571
# Epoch: 053, Train loss: 0.61614, Val loss: 0.47066
# Train - roc_auc:0.9192, ave_prec:0.5385, Val - roc_auc:0.9838, ave_prec:0.8976
# Train - precision:0.4624, recall:0.7963, Val - precision:0.6667, recall:0.8571
# Epoch: 054, Train loss: 0.61503, Val loss: 0.46446
# Train - roc_auc:0.9197, ave_prec:0.5364, Val - roc_auc:0.9838, ave_prec:0.8976
# Train - precision:0.4565, recall:0.7778, Val - precision:0.6667, recall:0.8571
# Epoch: 055, Train loss: 0.59478, Val loss: 0.46240
# Train - roc_auc:0.9205, ave_prec:0.5410, Val - roc_auc:0.9811, ave_prec:0.8857
# Train - precision:0.4574, recall:0.7963, Val - precision:0.6667, recall:0.8571
# Epoch: 056, Train loss: 0.59723, Val loss: 0.47167
# Train - roc_auc:0.9228, ave_prec:0.5532, Val - roc_auc:0.9838, ave_prec:0.8976
# Train - precision:0.4490, recall:0.8148, Val - precision:0.6667, recall:0.8571
# Epoch: 057, Train loss: 0.60040, Val loss: 0.46256
# Train - roc_auc:0.9229, ave_prec:0.5506, Val - roc_auc:0.9838, ave_prec:0.8976
# Train - precision:0.4624, recall:0.7963, Val - precision:0.6667, recall:0.8571
# Epoch: 058, Train loss: 0.58306, Val loss: 0.45698
# Train - roc_auc:0.9231, ave_prec:0.5517, Val - roc_auc:0.9811, ave_prec:0.8857
# Train - precision:0.4624, recall:0.7963, Val - precision:0.6667, recall:0.8571
# Epoch: 059, Train loss: 0.58813, Val loss: 0.45557
# Train - roc_auc:0.9241, ave_prec:0.5516, Val - roc_auc:0.9811, ave_prec:0.8857
# Train - precision:0.4674, recall:0.7963, Val - precision:0.6667, recall:0.8571
# Epoch: 060, Train loss: 0.58233, Val loss: 0.45741
# Train - roc_auc:0.9252, ave_prec:0.5593, Val - roc_auc:0.9838, ave_prec:0.8976
# Train - precision:0.4725, recall:0.7963, Val - precision:0.6667, recall:0.8571
# Epoch: 061, Train loss: 0.58607, Val loss: 0.45408
# Train - roc_auc:0.9254, ave_prec:0.5573, Val - roc_auc:0.9838, ave_prec:0.8976
# Train - precision:0.4839, recall:0.8333, Val - precision:0.6667, recall:0.8571
# Epoch: 062, Train loss: 0.57171, Val loss: 0.44929
# Train - roc_auc:0.9250, ave_prec:0.5545, Val - roc_auc:0.9838, ave_prec:0.8976
# Train - precision:0.4725, recall:0.7963, Val - precision:0.6667, recall:0.8571
# Epoch: 063, Train loss: 0.57658, Val loss: 0.45021
# Train - roc_auc:0.9266, ave_prec:0.5642, Val - roc_auc:0.9811, ave_prec:0.8857
# Train - precision:0.4896, recall:0.8704, Val - precision:0.6667, recall:0.8571
# Epoch: 064, Train loss: 0.56068, Val loss: 0.44460
# Train - roc_auc:0.9270, ave_prec:0.5636, Val - roc_auc:0.9811, ave_prec:0.8857
# Train - precision:0.4946, recall:0.8519, Val - precision:0.6667, recall:0.8571
# Epoch: 065, Train loss: 0.56349, Val loss: 0.44755
# Train - roc_auc:0.9284, ave_prec:0.5704, Val - roc_auc:0.9838, ave_prec:0.8976
# Train - precision:0.5000, recall:0.8704, Val - precision:0.6667, recall:0.8571
# Epoch: 066, Train loss: 0.56617, Val loss: 0.43992
# Train - roc_auc:0.9286, ave_prec:0.5648, Val - roc_auc:0.9811, ave_prec:0.8857
# Train - precision:0.5000, recall:0.8704, Val - precision:0.6667, recall:0.8571
# Epoch: 067, Train loss: 0.55198, Val loss: 0.43881
# Train - roc_auc:0.9288, ave_prec:0.5670, Val - roc_auc:0.9811, ave_prec:0.8857
# Train - precision:0.4946, recall:0.8519, Val - precision:0.6667, recall:0.8571
# Epoch: 068, Train loss: 0.55233, Val loss: 0.43838
# Train - roc_auc:0.9297, ave_prec:0.5671, Val - roc_auc:0.9838, ave_prec:0.8976
# Train - precision:0.4946, recall:0.8519, Val - precision:0.6667, recall:0.8571
# Epoch: 069, Train loss: 0.56099, Val loss: 0.43765
# Train - roc_auc:0.9304, ave_prec:0.5722, Val - roc_auc:0.9811, ave_prec:0.8857
# Train - precision:0.5053, recall:0.8889, Val - precision:0.6667, recall:0.8571
# Epoch: 070, Train loss: 0.54396, Val loss: 0.43312
# Train - roc_auc:0.9308, ave_prec:0.5746, Val - roc_auc:0.9811, ave_prec:0.8857
# Train - precision:0.5053, recall:0.8889, Val - precision:0.6667, recall:0.8571
# Epoch: 071, Train loss: 0.54657, Val loss: 0.42795
# Train - roc_auc:0.9306, ave_prec:0.5692, Val - roc_auc:0.9811, ave_prec:0.8857
# Train - precision:0.5053, recall:0.8889, Val - precision:0.6667, recall:0.8571
# Epoch: 072, Train loss: 0.53781, Val loss: 0.42256
# Train - roc_auc:0.9318, ave_prec:0.5738, Val - roc_auc:0.9811, ave_prec:0.8857
# Train - precision:0.5000, recall:0.8889, Val - precision:0.6667, recall:0.8571
# Epoch: 073, Train loss: 0.52820, Val loss: 0.42055
# Train - roc_auc:0.9330, ave_prec:0.5778, Val - roc_auc:0.9811, ave_prec:0.8857
# Train - precision:0.4848, recall:0.8889, Val - precision:0.6667, recall:0.8571
# Epoch: 074, Train loss: 0.54491, Val loss: 0.41669
# Train - roc_auc:0.9331, ave_prec:0.5757, Val - roc_auc:0.9811, ave_prec:0.8857
# Train - precision:0.4948, recall:0.8889, Val - precision:0.6250, recall:0.7143
# Epoch: 075, Train loss: 0.53022, Val loss: 0.41215
# Train - roc_auc:0.9329, ave_prec:0.5769, Val - roc_auc:0.9811, ave_prec:0.8857
# Train - precision:0.4898, recall:0.8889, Val - precision:0.6250, recall:0.7143
# Epoch: 076, Train loss: 0.53136, Val loss: 0.41320
# Train - roc_auc:0.9341, ave_prec:0.5738, Val - roc_auc:0.9811, ave_prec:0.8857
# Train - precision:0.5000, recall:0.8889, Val - precision:0.6250, recall:0.7143
# Epoch: 077, Train loss: 0.54903, Val loss: 0.41768
# Train - roc_auc:0.9351, ave_prec:0.5839, Val - roc_auc:0.9784, ave_prec:0.8766
# Train - precision:0.5000, recall:0.8889, Val - precision:0.6250, recall:0.7143
# Epoch: 078, Train loss: 0.51660, Val loss: 0.41423
# Train - roc_auc:0.9355, ave_prec:0.5842, Val - roc_auc:0.9784, ave_prec:0.8766
# Train - precision:0.5053, recall:0.8889, Val - precision:0.6250, recall:0.7143
# Epoch: 079, Train loss: 0.51741, Val loss: 0.41974
# Train - roc_auc:0.9363, ave_prec:0.5859, Val - roc_auc:0.9784, ave_prec:0.8766
# Train - precision:0.5000, recall:0.8889, Val - precision:0.6250, recall:0.7143
# Epoch: 080, Train loss: 0.51187, Val loss: 0.41870
# Train - roc_auc:0.9367, ave_prec:0.5853, Val - roc_auc:0.9784, ave_prec:0.8766
# Train - precision:0.5053, recall:0.8889, Val - precision:0.6250, recall:0.7143
# Epoch: 081, Train loss: 0.50808, Val loss: 0.41801
# Train - roc_auc:0.9373, ave_prec:0.5878, Val - roc_auc:0.9784, ave_prec:0.8766
# Train - precision:0.5106, recall:0.8889, Val - precision:0.6250, recall:0.7143
# Epoch: 082, Train loss: 0.51624, Val loss: 0.42161
# Train - roc_auc:0.9377, ave_prec:0.5870, Val - roc_auc:0.9784, ave_prec:0.8766
# Train - precision:0.5106, recall:0.8889, Val - precision:0.8333, recall:0.7143
# Epoch: 083, Train loss: 0.49490, Val loss: 0.41323
# Train - roc_auc:0.9383, ave_prec:0.5903, Val - roc_auc:0.9784, ave_prec:0.8766
# Train - precision:0.5106, recall:0.8889, Val - precision:0.8333, recall:0.7143
# Epoch: 084, Train loss: 0.50014, Val loss: 0.41185
# Train - roc_auc:0.9401, ave_prec:0.6013, Val - roc_auc:0.9784, ave_prec:0.8766
# Train - precision:0.4948, recall:0.8889, Val - precision:0.7143, recall:0.7143
# Epoch: 085, Train loss: 0.49395, Val loss: 0.41499
# Train - roc_auc:0.9403, ave_prec:0.6044, Val - roc_auc:0.9784, ave_prec:0.8766
# Train - precision:0.4898, recall:0.8889, Val - precision:0.6250, recall:0.7143
# Epoch: 086, Train loss: 0.50098, Val loss: 0.41434
# Train - roc_auc:0.9413, ave_prec:0.6109, Val - roc_auc:0.9784, ave_prec:0.8766
# Train - precision:0.4800, recall:0.8889, Val - precision:0.6250, recall:0.7143
# Epoch: 087, Train loss: 0.49222, Val loss: 0.41899
# Train - roc_auc:0.9419, ave_prec:0.6075, Val - roc_auc:0.9784, ave_prec:0.8766
# Train - precision:0.4948, recall:0.8889, Val - precision:0.7143, recall:0.7143
# Epoch: 088, Train loss: 0.47934, Val loss: 0.42210
# Train - roc_auc:0.9418, ave_prec:0.6083, Val - roc_auc:0.9784, ave_prec:0.8766
# Train - precision:0.5053, recall:0.8889, Val - precision:0.8333, recall:0.7143
# Epoch: 089, Train loss: 0.48537, Val loss: 0.42327
# Train - roc_auc:0.9425, ave_prec:0.6125, Val - roc_auc:0.9784, ave_prec:0.8766
# Train - precision:0.4948, recall:0.8889, Val - precision:0.7143, recall:0.7143
# Epoch: 090, Train loss: 0.47476, Val loss: 0.42619
# Train - roc_auc:0.9435, ave_prec:0.6153, Val - roc_auc:0.9784, ave_prec:0.8766
# Train - precision:0.5053, recall:0.8889, Val - precision:0.8333, recall:0.7143
# Epoch: 091, Train loss: 0.48195, Val loss: 0.42549
# Train - roc_auc:0.9440, ave_prec:0.6178, Val - roc_auc:0.9730, ave_prec:0.8595
# Train - precision:0.4948, recall:0.8889, Val - precision:0.7143, recall:0.7143
# Epoch: 092, Train loss: 0.46734, Val loss: 0.42766
# Train - roc_auc:0.9447, ave_prec:0.6161, Val - roc_auc:0.9757, ave_prec:0.8690
# Train - precision:0.5053, recall:0.8889, Val - precision:0.8333, recall:0.7143
# Epoch: 093, Train loss: 0.47089, Val loss: 0.42672
# Train - roc_auc:0.9452, ave_prec:0.6176, Val - roc_auc:0.9757, ave_prec:0.8690
# Train - precision:0.5000, recall:0.8889, Val - precision:0.7143, recall:0.7143
# Epoch: 094, Train loss: 0.46033, Val loss: 0.42770
# Train - roc_auc:0.9450, ave_prec:0.6156, Val - roc_auc:0.9784, ave_prec:0.8810
# Train - precision:0.5106, recall:0.8889, Val - precision:0.8333, recall:0.7143
# Epoch: 095, Train loss: 0.45485, Val loss: 0.43323
# Train - roc_auc:0.9454, ave_prec:0.6132, Val - roc_auc:0.9784, ave_prec:0.8898
# Train - precision:0.5275, recall:0.8889, Val - precision:0.8333, recall:0.7143
# Epoch: 096, Train loss: 0.44834, Val loss: 0.42672
# Train - roc_auc:0.9458, ave_prec:0.6209, Val - roc_auc:0.9757, ave_prec:0.8745
# Train - precision:0.5161, recall:0.8889, Val - precision:0.8333, recall:0.7143
# Epoch: 097, Train loss: 0.45124, Val loss: 0.43471
# Train - roc_auc:0.9462, ave_prec:0.6227, Val - roc_auc:0.9730, ave_prec:0.8626
# Train - precision:0.5161, recall:0.8889, Val - precision:0.8333, recall:0.7143
# Epoch: 098, Train loss: 0.44921, Val loss: 0.44196
# Train - roc_auc:0.9459, ave_prec:0.6262, Val - roc_auc:0.9757, ave_prec:0.8844
# Train - precision:0.5217, recall:0.8889, Val - precision:0.8333, recall:0.7143
# Epoch: 099, Train loss: 0.45006, Val loss: 0.43813
# Train - roc_auc:0.9471, ave_prec:0.6277, Val - roc_auc:0.9730, ave_prec:0.8796
# Train - precision:0.5161, recall:0.8889, Val - precision:0.8333, recall:0.7143
# Epoch: 100, Train loss: 0.43770, Val loss: 0.43375
# Train - roc_auc:0.9479, ave_prec:0.6336, Val - roc_auc:0.9730, ave_prec:0.8796
# Train - precision:0.5161, recall:0.8889, Val - precision:0.8333, recall:0.7143
# Test loss: 0.78549
# Test - roc_auc:0.8810, ave_prec:0.6619
# Test - precision:0.4167, recall:0.7143

# %%
tr_precision, tr_recall = test_precision_recall(model, train_loader, pred_th=0.8)
val_precision, val_recall  = test_precision_recall(model, val_loader, pred_th=0.8)
print('Train - precision:{:.4f}, recall:{:.4f}, Val - precision:{:.4f}, recall:{:.4f}'.format(
    tr_precision, tr_recall, val_precision, val_recall))
te_precision, te_recall = test_precision_recall(model, test_loader, pred_th=0.8)
print('Test - precision:{:.4f}, recall:{:.4f}'.format(te_precision, te_recall))
# Out:
# Train - precision:0.5375, recall:0.7963, Val - precision:0.8333, recall:0.7143
# Test - precision:0.5556, recall:0.7143

# %%
#torch.save(model, 'trained_models/AFP_tl_amg_0.85093')
torch.save(model, 'trained_models/AFP_tl_amg_test')

# %%
model = torch.load('trained_models/AFP_tl_amg_0.85093')
te_score = test(model, test_loader)
print('Test: {:.5f}'.format(te_score))
