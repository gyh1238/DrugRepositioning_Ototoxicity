# %%
import numpy as np
import torch

#check GPU
print('CUDA available: {}'.format(torch.cuda.is_available()))
print('Current GPU: {}'.format(torch.cuda.get_device_name(torch.cuda.current_device())))
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Out:
# CUDA available: True
# Current GPU: GeForce RTX 2080 SUPER

# %%
import deepchem as dc

loaded, datasets, transformers = dc.utils.load_dataset_from_disk('data/combined/cisplatin')
train_dataset, valid_dataset, test_dataset = datasets
print('train/val/test split: {}/{}/{}'.format(
    len(train_dataset), len(valid_dataset), len(test_dataset)))
# Out:
# train/val/test split: 490/61/61

# %%
num_node_features = train_dataset.X[0].num_node_features
num_edge_features = train_dataset.X[0].num_edge_features
num_classes = train_dataset.y[0].shape[-1]
print(num_node_features, num_classes)
# Out:
# 79 1

# %%
from torch_geometric.data import Data, DataLoader

def get_data_loader(dc_dataset, batch_size=64, shuffle=True):
    ds = [x.to_pyg_graph() for x in dc_dataset.X]
    for i in range(len(ds)):
        ds[i].y = torch.from_numpy(dc_dataset.y[i].reshape(1, -1))
        ds[i].w = torch.from_numpy(dc_dataset.w[i].reshape(1, -1))
    return DataLoader(ds, batch_size=batch_size, shuffle=shuffle)

train_loader = get_data_loader(train_dataset, batch_size=64, shuffle=True)
val_loader = get_data_loader(valid_dataset, batch_size=64, shuffle=True)
test_loader = get_data_loader(test_dataset, batch_size=64, shuffle=True)

for step, data in enumerate(train_loader):
    print('Step {}:'.format(step + 1))
    print('=======')
    print('Number of graphs in the current batch: {}'.format(data.num_graphs))
    print(data, '\n')
# Out:
# RDKit WARNING: [02:20:33] Enabling RDKit 2019.09.3 jupyter extensions
# Step 1:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1395], edge_attr=[3012, 12], edge_index=[2, 3012], ptr=[65], w=[64, 1], x=[1395, 79], y=[64, 1])
#
# Step 2:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1444], edge_attr=[3084, 12], edge_index=[2, 3084], ptr=[65], w=[64, 1], x=[1444, 79], y=[64, 1])
#
# Step 3:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1390], edge_attr=[2930, 12], edge_index=[2, 2930], ptr=[65], w=[64, 1], x=[1390, 79], y=[64, 1])
#
# Step 4:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1402], edge_attr=[3016, 12], edge_index=[2, 3016], ptr=[65], w=[64, 1], x=[1402, 79], y=[64, 1])
#
# Step 5:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1468], edge_attr=[3184, 12], edge_index=[2, 3184], ptr=[65], w=[64, 1], x=[1468, 79], y=[64, 1])
#
# Step 6:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1387], edge_attr=[2982, 12], edge_index=[2, 2982], ptr=[65], w=[64, 1], x=[1387, 79], y=[64, 1])
#
# Step 7:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1381], edge_attr=[2974, 12], edge_index=[2, 2974], ptr=[65], w=[64, 1], x=[1381, 79], y=[64, 1])
#
# Step 8:
# =======
# Number of graphs in the current batch: 42
# Batch(batch=[983], edge_attr=[2114, 12], edge_index=[2, 2114], ptr=[43], w=[42, 1], x=[983, 79], y=[42, 1])

# %%
from sklearn.metrics import roc_auc_score, average_precision_score
from sklearn.metrics import precision_score, recall_score

def train(model, optimizer, criterion):
    model.train()

    for data in train_loader:  # Iterate in batches over the training dataset.
        data = data.to(device)
        
        out = model(data.x, data.edge_index, data.edge_attr, data.batch)
        
        #loss = criterion(out, data.y)
        loss = criterion(out, data.y, weights=data.w)
        
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

def test(model, loader):
    model.eval()

    outs = []
    ys = []
    for data in loader:  # Iterate in batches over the training/test dataset.
        data = data.to(device)
        
        #out = model(data.x, data.edge_index, data.batch)  # Perform a single forward pass.
        out = model(data.x, data.edge_index, data.edge_attr, data.batch)
        
        outs.append(out.detach().cpu().numpy())
        ys.append(data.y.detach().cpu().numpy())
    
    pred = np.concatenate(outs, axis=0)
    y = np.concatenate(ys, axis=0)
    
    roc_auc = roc_auc_score(y, pred)
    ave_prec = average_precision_score(y, pred)
    return roc_auc, ave_prec

def test_precision_recall(model, loader, pred_th=0.5):
    model.eval()

    outs = []
    ys = []
    for data in loader:  # Iterate in batches over the training/test dataset.
        data = data.to(device)
        
        out = model(data.x, data.edge_index, 
                     data.edge_attr, data.batch)
        
        outs.append(out.detach().cpu().numpy())
        ys.append(data.y.detach().cpu().numpy())
    
    pred = np.concatenate(outs, axis=0)
    y = np.concatenate(ys, axis=0).astype(int)
    binary_pred = (pred > pred_th).astype(int)
    
    precision = precision_score(y, binary_pred, zero_division=0)
    recall = recall_score(y, binary_pred, zero_division=0)
    return precision, recall

def get_loss(model, loader):
    model.eval()

    losses = []
    for data in loader:
        data = data.to(device)
        out = model(data.x, data.edge_index, data.edge_attr, data.batch)
        loss = criterion(out, data.y, data.w)
        losses.append(loss.detach().cpu().numpy())
    return np.mean(losses)

# %%
from models import AttentiveFP

model = AttentiveFP(in_channels=num_node_features, hidden_channels=512, 
                    out_channels=num_classes, edge_dim=num_edge_features, 
                    num_layers=4, num_timesteps=3,
                    dropout=0.4).to(device)
print(model)
# Out:
# AttentiveFP(
#   (lin1): Linear(in_features=79, out_features=512, bias=True)
#   (atom_convs): ModuleList(
#     (0): GATEConv(
#       (lin1): Linear(in_features=524, out_features=512, bias=False)
#       (lin2): Linear(in_features=512, out_features=512, bias=False)
#     )
#     (1): GATConv(512, 512, heads=1)
#     (2): GATConv(512, 512, heads=1)
#     (3): GATConv(512, 512, heads=1)
#   )
#   (atom_grus): ModuleList(
#     (0): GRUCell(512, 512)
#     (1): GRUCell(512, 512)
#     (2): GRUCell(512, 512)
#     (3): GRUCell(512, 512)
#   )
#   (atom_norms): ModuleList(
#     (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     (2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     (3): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   )
#   (mol_conv): GATConv(512, 512, heads=1)
#   (mol_gru): GRUCell(512, 512)
#   (lin2): Linear(in_features=512, out_features=1, bias=True)
# )

# %%
#transfer learning step

model_state_dict = model.state_dict()

pretrained_model = torch.load('pretrained_models/AFP_0.72710')
#pretrained_model = torch.load('pretrained_models/AFP_0.71991')
pretrained_state_dict = pretrained_model.state_dict()
sel_pretrained_state_dict = {k: v for k, v in pretrained_state_dict.items() 
                             if model_state_dict[k].size() == v.size()}
model_state_dict.update(sel_pretrained_state_dict) 
model.load_state_dict(model_state_dict)
# Out:
# <All keys matched successfully>

# %%
for p in model.parameters():
    p.requires_grad = False
for p in model.lin2.parameters():
    p.requires_grad = True

# %%
from loss import PrecisionAtRecallLoss, PrecisionRecallAUCLoss, PrecisionRecallAUCLoss2

#optimizer = torch.optim.Adam(model.parameters(), lr=3e-5)
optimizer = torch.optim.RMSprop(model.parameters(), lr=1e-4)
#criterion = torch.nn.BCEWithLogitsLoss(reduction='none')
#criterion = RecallAtPrecisionLoss(num_classes=num_classes, target_precision=0.9).to(device)
#criterion = PrecisionAtRecallLoss(num_classes=num_classes, target_recall=0.5).to(device)
#criterion = PrecisionAtRecallLoss(
#    num_classes=num_classes, target_recall=0.1, surrogate_type='hinge').to(device)
#criterion = PrecisionRecallAUCLoss(
#    num_classes=num_classes, precision_range=(0.0, 0.5)).to(device)
criterion = PrecisionRecallAUCLoss2(
    num_classes=num_classes, recall_range=(0.0, 1.0)).to(device)


for epoch in range(1, 31):
    train(model, optimizer, criterion)
    tr_loss = get_loss(model, train_loader)
    val_loss = get_loss(model, val_loader)
    print('Epoch: {:03d}, Train loss: {:.5f}, Val loss: {:.5f}'.format(
        epoch, tr_loss, val_loss))
    
    tr_roc_auc, tr_ave_prec = test(model, train_loader)
    val_roc_auc, val_ave_prec  = test(model, val_loader)
    print('Train - roc_auc:{:.4f}, ave_prec:{:.4f}, Val - roc_auc:{:.4f}, ave_prec:{:.4f}'.format(
        tr_roc_auc, tr_ave_prec, val_roc_auc, val_ave_prec))
    
    tr_precision, tr_recall = test_precision_recall(model, train_loader)
    val_precision, val_recall  = test_precision_recall(model, val_loader)
    print('Train - precision:{:.4f}, recall:{:.4f}, Val - precision:{:.4f}, recall:{:.4f}'.format(
        tr_precision, tr_recall, val_precision, val_recall))
    
te_loss  = get_loss(model, test_loader)
print('Test loss: {:.5f}'.format(te_loss))
te_roc_auc, te_ave_prec = test(model, test_loader)
print('Test - roc_auc:{:.4f}, ave_prec:{:.4f}'.format(te_roc_auc, te_ave_prec))
te_precision, te_recall = test_precision_recall(model, test_loader)
print('Test - precision:{:.4f}, recall:{:.4f}'.format(te_precision, te_recall))
# Out:
# Epoch: 001, Train loss: 1.12833, Val loss: 1.12112
# Train - roc_auc:0.7254, ave_prec:0.2464, Val - roc_auc:0.7453, ave_prec:0.4107
# Train - precision:0.2692, recall:0.2333, Val - precision:0.4000, recall:0.2500
# Epoch: 002, Train loss: 1.08298, Val loss: 1.09386
# Train - roc_auc:0.7567, ave_prec:0.2668, Val - roc_auc:0.7877, ave_prec:0.4834
# Train - precision:0.3095, recall:0.4333, Val - precision:0.3333, recall:0.3750
# Epoch: 003, Train loss: 1.08307, Val loss: 1.07962
# Train - roc_auc:0.7642, ave_prec:0.2706, Val - roc_auc:0.7948, ave_prec:0.4887
# Train - precision:0.3187, recall:0.4833, Val - precision:0.3333, recall:0.3750
# Epoch: 004, Train loss: 1.05844, Val loss: 1.06894
# Train - roc_auc:0.7703, ave_prec:0.2727, Val - roc_auc:0.7995, ave_prec:0.4905
# Train - precision:0.3158, recall:0.5000, Val - precision:0.2500, recall:0.3750
# Epoch: 005, Train loss: 1.04664, Val loss: 1.05952
# Train - roc_auc:0.7735, ave_prec:0.2736, Val - roc_auc:0.8019, ave_prec:0.4924
# Train - precision:0.3000, recall:0.5000, Val - precision:0.2143, recall:0.3750
# Epoch: 006, Train loss: 1.04272, Val loss: 1.05176
# Train - roc_auc:0.7757, ave_prec:0.2754, Val - roc_auc:0.7995, ave_prec:0.4909
# Train - precision:0.3048, recall:0.5333, Val - precision:0.2143, recall:0.3750
# Epoch: 007, Train loss: 1.03333, Val loss: 1.04552
# Train - roc_auc:0.7779, ave_prec:0.2760, Val - roc_auc:0.8019, ave_prec:0.4920
# Train - precision:0.3048, recall:0.5333, Val - precision:0.2667, recall:0.5000
# Epoch: 008, Train loss: 1.03202, Val loss: 1.04071
# Train - roc_auc:0.7789, ave_prec:0.2761, Val - roc_auc:0.8042, ave_prec:0.5107
# Train - precision:0.3113, recall:0.5500, Val - precision:0.2667, recall:0.5000
# Epoch: 009, Train loss: 1.03031, Val loss: 1.03536
# Train - roc_auc:0.7805, ave_prec:0.2767, Val - roc_auc:0.7995, ave_prec:0.5079
# Train - precision:0.3113, recall:0.5500, Val - precision:0.2667, recall:0.5000
# Epoch: 010, Train loss: 1.02489, Val loss: 1.03064
# Train - roc_auc:0.7815, ave_prec:0.2778, Val - roc_auc:0.8019, ave_prec:0.5103
# Train - precision:0.3113, recall:0.5500, Val - precision:0.2667, recall:0.5000
# Epoch: 011, Train loss: 1.00876, Val loss: 1.02639
# Train - roc_auc:0.7822, ave_prec:0.2780, Val - roc_auc:0.8019, ave_prec:0.5103
# Train - precision:0.3178, recall:0.5667, Val - precision:0.2667, recall:0.5000
# Epoch: 012, Train loss: 1.02464, Val loss: 1.02285
# Train - roc_auc:0.7832, ave_prec:0.2784, Val - roc_auc:0.8019, ave_prec:0.5103
# Train - precision:0.3208, recall:0.5667, Val - precision:0.2667, recall:0.5000
# Epoch: 013, Train loss: 1.01444, Val loss: 1.01851
# Train - roc_auc:0.7846, ave_prec:0.2797, Val - roc_auc:0.8042, ave_prec:0.5115
# Train - precision:0.3208, recall:0.5667, Val - precision:0.2667, recall:0.5000
# Epoch: 014, Train loss: 1.00215, Val loss: 1.01376
# Train - roc_auc:0.7862, ave_prec:0.2807, Val - roc_auc:0.8090, ave_prec:0.5155
# Train - precision:0.3182, recall:0.5833, Val - precision:0.2667, recall:0.5000
# Epoch: 015, Train loss: 1.00683, Val loss: 1.00974
# Train - roc_auc:0.7875, ave_prec:0.2811, Val - roc_auc:0.8042, ave_prec:0.5127
# Train - precision:0.3182, recall:0.5833, Val - precision:0.2667, recall:0.5000
# Epoch: 016, Train loss: 0.99123, Val loss: 1.00696
# Train - roc_auc:0.7880, ave_prec:0.2812, Val - roc_auc:0.8042, ave_prec:0.5127
# Train - precision:0.3211, recall:0.5833, Val - precision:0.2667, recall:0.5000
# Epoch: 017, Train loss: 1.01161, Val loss: 1.00431
# Train - roc_auc:0.7881, ave_prec:0.2811, Val - roc_auc:0.8042, ave_prec:0.5127
# Train - precision:0.3241, recall:0.5833, Val - precision:0.2667, recall:0.5000
# Epoch: 018, Train loss: 0.98926, Val loss: 1.00070
# Train - roc_auc:0.7888, ave_prec:0.2813, Val - roc_auc:0.8090, ave_prec:0.5472
# Train - precision:0.3241, recall:0.5833, Val - precision:0.2667, recall:0.5000
# Epoch: 019, Train loss: 0.98554, Val loss: 0.99701
# Train - roc_auc:0.7894, ave_prec:0.2818, Val - roc_auc:0.8090, ave_prec:0.5472
# Train - precision:0.3211, recall:0.5833, Val - precision:0.2667, recall:0.5000
# Epoch: 020, Train loss: 1.00283, Val loss: 0.99425
# Train - roc_auc:0.7892, ave_prec:0.2816, Val - roc_auc:0.8090, ave_prec:0.5472
# Train - precision:0.3271, recall:0.5833, Val - precision:0.2667, recall:0.5000
# Epoch: 021, Train loss: 0.98236, Val loss: 0.99165
# Train - roc_auc:0.7895, ave_prec:0.2819, Val - roc_auc:0.8090, ave_prec:0.5472
# Train - precision:0.3333, recall:0.5833, Val - precision:0.2667, recall:0.5000
# Epoch: 022, Train loss: 0.98013, Val loss: 0.98914
# Train - roc_auc:0.7901, ave_prec:0.2815, Val - roc_auc:0.8090, ave_prec:0.5472
# Train - precision:0.3241, recall:0.5833, Val - precision:0.2667, recall:0.5000
# Epoch: 023, Train loss: 0.98017, Val loss: 0.98635
# Train - roc_auc:0.7911, ave_prec:0.2817, Val - roc_auc:0.8090, ave_prec:0.5472
# Train - precision:0.3211, recall:0.5833, Val - precision:0.2667, recall:0.5000
# Epoch: 024, Train loss: 0.97615, Val loss: 0.98375
# Train - roc_auc:0.7917, ave_prec:0.2818, Val - roc_auc:0.8090, ave_prec:0.5472
# Train - precision:0.3182, recall:0.5833, Val - precision:0.2667, recall:0.5000
# Epoch: 025, Train loss: 0.97249, Val loss: 0.98197
# Train - roc_auc:0.7921, ave_prec:0.2820, Val - roc_auc:0.8090, ave_prec:0.5472
# Train - precision:0.3211, recall:0.5833, Val - precision:0.2667, recall:0.5000
# Epoch: 026, Train loss: 0.98280, Val loss: 0.97904
# Train - roc_auc:0.7926, ave_prec:0.2825, Val - roc_auc:0.8090, ave_prec:0.5472
# Train - precision:0.3211, recall:0.5833, Val - precision:0.2667, recall:0.5000
# Epoch: 027, Train loss: 0.96969, Val loss: 0.97667
# Train - roc_auc:0.7930, ave_prec:0.2825, Val - roc_auc:0.8137, ave_prec:0.5524
# Train - precision:0.3211, recall:0.5833, Val - precision:0.2667, recall:0.5000
# Epoch: 028, Train loss: 0.96417, Val loss: 0.97510
# Train - roc_auc:0.7929, ave_prec:0.2828, Val - roc_auc:0.8137, ave_prec:0.5524
# Train - precision:0.3241, recall:0.5833, Val - precision:0.2667, recall:0.5000
# Epoch: 029, Train loss: 0.97415, Val loss: 0.97332
# Train - roc_auc:0.7933, ave_prec:0.2835, Val - roc_auc:0.8137, ave_prec:0.5524
# Train - precision:0.3269, recall:0.5667, Val - precision:0.2667, recall:0.5000
# Epoch: 030, Train loss: 0.97509, Val loss: 0.97069
# Train - roc_auc:0.7938, ave_prec:0.2844, Val - roc_auc:0.8137, ave_prec:0.5524
# Train - precision:0.3301, recall:0.5667, Val - precision:0.2667, recall:0.5000
# Test loss: 0.89807
# Test - roc_auc:0.8561, ave_prec:0.5009
# Test - precision:0.5000, recall:0.7500

# %%
tr_precision, tr_recall = test_precision_recall(model, train_loader, pred_th=0.8)
val_precision, val_recall  = test_precision_recall(model, val_loader, pred_th=0.8)
print('Train - precision:{:.4f}, recall:{:.4f}, Val - precision:{:.4f}, recall:{:.4f}'.format(
    tr_precision, tr_recall, val_precision, val_recall))
te_precision, te_recall = test_precision_recall(model, test_loader, pred_th=0.8)
print('Test - precision:{:.4f}, recall:{:.4f}'.format(te_precision, te_recall))
# Out:
# Train - precision:0.3243, recall:0.4000, Val - precision:0.4286, recall:0.3750
# Test - precision:0.3750, recall:0.3750

# %%
for p in model.parameters():
    p.requires_grad = True

# %%
optimizer = torch.optim.RMSprop(model.parameters(), lr=3e-6)
#criterion = torch.nn.BCEWithLogitsLoss(reduction='none')
#criterion = RecallAtPrecisionLoss(num_classes=num_classes, target_precision=0.99).to(device)
#criterion = PrecisionAtRecallLoss(num_classes=num_classes, target_recall=0.05).to(device)
#criterion = PrecisionAtRecallLoss(
#    num_classes=num_classes, target_recall=0.1, surrogate_type='hinge').to(device)
#criterion = PrecisionRecallAUCLoss(
#    num_classes=num_classes, precision_range=(0.5, 1.)).to(device)
criterion = PrecisionRecallAUCLoss2(
    num_classes=num_classes, recall_range=(0.0, 1.0)).to(device)


for epoch in range(1, 126):
    train(model, optimizer, criterion)
    tr_loss = get_loss(model, train_loader)
    val_loss = get_loss(model, val_loader)
    print('Epoch: {:03d}, Train loss: {:.5f}, Val loss: {:.5f}'.format(
        epoch, tr_loss, val_loss))
    
    tr_roc_auc, tr_ave_prec = test(model, train_loader)
    val_roc_auc, val_ave_prec  = test(model, val_loader)
    print('Train - roc_auc:{:.4f}, ave_prec:{:.4f}, Val - roc_auc:{:.4f}, ave_prec:{:.4f}'.format(
        tr_roc_auc, tr_ave_prec, val_roc_auc, val_ave_prec))
    
    tr_precision, tr_recall = test_precision_recall(model, train_loader)
    val_precision, val_recall  = test_precision_recall(model, val_loader)
    print('Train - precision:{:.4f}, recall:{:.4f}, Val - precision:{:.4f}, recall:{:.4f}'.format(
        tr_precision, tr_recall, val_precision, val_recall))
    
te_loss  = get_loss(model, test_loader)
print('Test loss: {:.5f}'.format(te_loss))
te_roc_auc, te_ave_prec = test(model, test_loader)
print('Test - roc_auc:{:.4f}, ave_prec:{:.4f}'.format(te_roc_auc, te_ave_prec))
te_precision, te_recall = test_precision_recall(model, test_loader)
print('Test - precision:{:.4f}, recall:{:.4f}'.format(te_precision, te_recall))
# Out:
# Epoch: 001, Train loss: 0.94413, Val loss: 0.93856
# Train - roc_auc:0.8111, ave_prec:0.3035, Val - roc_auc:0.8231, ave_prec:0.5313
# Train - precision:0.3495, recall:0.6000, Val - precision:0.3077, recall:0.5000
# Epoch: 002, Train loss: 0.91640, Val loss: 0.93348
# Train - roc_auc:0.8181, ave_prec:0.3125, Val - roc_auc:0.8231, ave_prec:0.5314
# Train - precision:0.3646, recall:0.5833, Val - precision:0.3333, recall:0.5000
# Epoch: 003, Train loss: 0.90515, Val loss: 0.93619
# Train - roc_auc:0.8217, ave_prec:0.3177, Val - roc_auc:0.8231, ave_prec:0.5314
# Train - precision:0.3596, recall:0.5333, Val - precision:0.3333, recall:0.5000
# Epoch: 004, Train loss: 0.89451, Val loss: 0.91279
# Train - roc_auc:0.8286, ave_prec:0.3278, Val - roc_auc:0.8349, ave_prec:0.5432
# Train - precision:0.3776, recall:0.6167, Val - precision:0.3077, recall:0.5000
# Epoch: 005, Train loss: 0.88383, Val loss: 0.90003
# Train - roc_auc:0.8343, ave_prec:0.3323, Val - roc_auc:0.8373, ave_prec:0.5500
# Train - precision:0.3981, recall:0.6833, Val - precision:0.3077, recall:0.5000
# Epoch: 006, Train loss: 0.87701, Val loss: 0.90128
# Train - roc_auc:0.8367, ave_prec:0.3367, Val - roc_auc:0.8349, ave_prec:0.5485
# Train - precision:0.3900, recall:0.6500, Val - precision:0.3077, recall:0.5000
# Epoch: 007, Train loss: 0.87694, Val loss: 0.89700
# Train - roc_auc:0.8389, ave_prec:0.3384, Val - roc_auc:0.8396, ave_prec:0.5520
# Train - precision:0.3900, recall:0.6500, Val - precision:0.3077, recall:0.5000
# Epoch: 008, Train loss: 0.85834, Val loss: 0.88757
# Train - roc_auc:0.8428, ave_prec:0.3473, Val - roc_auc:0.8373, ave_prec:0.5334
# Train - precision:0.3900, recall:0.6500, Val - precision:0.3077, recall:0.5000
# Epoch: 009, Train loss: 0.85823, Val loss: 0.88129
# Train - roc_auc:0.8466, ave_prec:0.3492, Val - roc_auc:0.8420, ave_prec:0.5437
# Train - precision:0.3960, recall:0.6667, Val - precision:0.3077, recall:0.5000
# Epoch: 010, Train loss: 0.84025, Val loss: 0.87187
# Train - roc_auc:0.8504, ave_prec:0.3564, Val - roc_auc:0.8420, ave_prec:0.5437
# Train - precision:0.4057, recall:0.7167, Val - precision:0.3077, recall:0.5000
# Epoch: 011, Train loss: 0.82970, Val loss: 0.86860
# Train - roc_auc:0.8525, ave_prec:0.3605, Val - roc_auc:0.8443, ave_prec:0.5451
# Train - precision:0.4095, recall:0.7167, Val - precision:0.3077, recall:0.5000
# Epoch: 012, Train loss: 0.82671, Val loss: 0.86354
# Train - roc_auc:0.8545, ave_prec:0.3662, Val - roc_auc:0.8491, ave_prec:0.5489
# Train - precision:0.4095, recall:0.7167, Val - precision:0.3077, recall:0.5000
# Epoch: 013, Train loss: 0.83112, Val loss: 0.85675
# Train - roc_auc:0.8568, ave_prec:0.3697, Val - roc_auc:0.8514, ave_prec:0.5505
# Train - precision:0.4000, recall:0.7333, Val - precision:0.3077, recall:0.5000
# Epoch: 014, Train loss: 0.83571, Val loss: 0.85561
# Train - roc_auc:0.8589, ave_prec:0.3714, Val - roc_auc:0.8538, ave_prec:0.5692
# Train - precision:0.4095, recall:0.7167, Val - precision:0.3077, recall:0.5000
# Epoch: 015, Train loss: 0.81810, Val loss: 0.85023
# Train - roc_auc:0.8618, ave_prec:0.3753, Val - roc_auc:0.8538, ave_prec:0.5692
# Train - precision:0.4095, recall:0.7167, Val - precision:0.3077, recall:0.5000
# Epoch: 016, Train loss: 0.80945, Val loss: 0.84690
# Train - roc_auc:0.8630, ave_prec:0.3770, Val - roc_auc:0.8538, ave_prec:0.5692
# Train - precision:0.4158, recall:0.7000, Val - precision:0.3636, recall:0.5000
# Epoch: 017, Train loss: 0.80688, Val loss: 0.84269
# Train - roc_auc:0.8656, ave_prec:0.3801, Val - roc_auc:0.8538, ave_prec:0.5692
# Train - precision:0.4272, recall:0.7333, Val - precision:0.3636, recall:0.5000
# Epoch: 018, Train loss: 0.79943, Val loss: 0.84153
# Train - roc_auc:0.8674, ave_prec:0.3840, Val - roc_auc:0.8538, ave_prec:0.5692
# Train - precision:0.4257, recall:0.7167, Val - precision:0.3636, recall:0.5000
# Epoch: 019, Train loss: 0.80714, Val loss: 0.83743
# Train - roc_auc:0.8678, ave_prec:0.3863, Val - roc_auc:0.8538, ave_prec:0.5692
# Train - precision:0.4286, recall:0.7000, Val - precision:0.3636, recall:0.5000
# Epoch: 020, Train loss: 0.79404, Val loss: 0.83971
# Train - roc_auc:0.8689, ave_prec:0.3880, Val - roc_auc:0.8514, ave_prec:0.5677
# Train - precision:0.4375, recall:0.7000, Val - precision:0.4000, recall:0.5000
# Epoch: 021, Train loss: 0.78956, Val loss: 0.83629
# Train - roc_auc:0.8704, ave_prec:0.3936, Val - roc_auc:0.8538, ave_prec:0.5697
# Train - precision:0.4433, recall:0.7167, Val - precision:0.4000, recall:0.5000
# Epoch: 022, Train loss: 0.77948, Val loss: 0.83104
# Train - roc_auc:0.8721, ave_prec:0.3970, Val - roc_auc:0.8561, ave_prec:0.5649
# Train - precision:0.4444, recall:0.7333, Val - precision:0.4000, recall:0.5000
# Epoch: 023, Train loss: 0.78872, Val loss: 0.82649
# Train - roc_auc:0.8739, ave_prec:0.3998, Val - roc_auc:0.8608, ave_prec:0.5764
# Train - precision:0.4455, recall:0.7500, Val - precision:0.3636, recall:0.5000
# Epoch: 024, Train loss: 0.78102, Val loss: 0.83006
# Train - roc_auc:0.8756, ave_prec:0.4038, Val - roc_auc:0.8585, ave_prec:0.5677
# Train - precision:0.4388, recall:0.7167, Val - precision:0.4000, recall:0.5000
# Epoch: 025, Train loss: 0.77532, Val loss: 0.83264
# Train - roc_auc:0.8769, ave_prec:0.4066, Val - roc_auc:0.8561, ave_prec:0.5651
# Train - precision:0.4516, recall:0.7000, Val - precision:0.4444, recall:0.5000
# Epoch: 026, Train loss: 0.76253, Val loss: 0.82630
# Train - roc_auc:0.8776, ave_prec:0.4120, Val - roc_auc:0.8585, ave_prec:0.5839
# Train - precision:0.4615, recall:0.7000, Val - precision:0.4000, recall:0.5000
# Epoch: 027, Train loss: 0.79676, Val loss: 0.82369
# Train - roc_auc:0.8788, ave_prec:0.4161, Val - roc_auc:0.8561, ave_prec:0.5719
# Train - precision:0.4516, recall:0.7000, Val - precision:0.4000, recall:0.5000
# Epoch: 028, Train loss: 0.76152, Val loss: 0.82102
# Train - roc_auc:0.8805, ave_prec:0.4197, Val - roc_auc:0.8585, ave_prec:0.5673
# Train - precision:0.4583, recall:0.7333, Val - precision:0.4000, recall:0.5000
# Epoch: 029, Train loss: 0.76320, Val loss: 0.81719
# Train - roc_auc:0.8826, ave_prec:0.4261, Val - roc_auc:0.8608, ave_prec:0.5692
# Train - precision:0.4632, recall:0.7333, Val - precision:0.4000, recall:0.5000
# Epoch: 030, Train loss: 0.75586, Val loss: 0.81346
# Train - roc_auc:0.8836, ave_prec:0.4283, Val - roc_auc:0.8632, ave_prec:0.5716
# Train - precision:0.4688, recall:0.7500, Val - precision:0.4444, recall:0.5000
# Epoch: 031, Train loss: 0.74429, Val loss: 0.81492
# Train - roc_auc:0.8848, ave_prec:0.4293, Val - roc_auc:0.8608, ave_prec:0.5692
# Train - precision:0.4639, recall:0.7500, Val - precision:0.4000, recall:0.5000
# Epoch: 032, Train loss: 0.73945, Val loss: 0.81320
# Train - roc_auc:0.8860, ave_prec:0.4310, Val - roc_auc:0.8656, ave_prec:0.5748
# Train - precision:0.4694, recall:0.7667, Val - precision:0.3636, recall:0.5000
# Epoch: 033, Train loss: 0.74056, Val loss: 0.81118
# Train - roc_auc:0.8869, ave_prec:0.4326, Val - roc_auc:0.8656, ave_prec:0.5748
# Train - precision:0.4510, recall:0.7667, Val - precision:0.3636, recall:0.5000
# Epoch: 034, Train loss: 0.73508, Val loss: 0.80736
# Train - roc_auc:0.8881, ave_prec:0.4360, Val - roc_auc:0.8679, ave_prec:0.5772
# Train - precision:0.4434, recall:0.7833, Val - precision:0.3636, recall:0.5000
# Epoch: 035, Train loss: 0.74718, Val loss: 0.80739
# Train - roc_auc:0.8888, ave_prec:0.4355, Val - roc_auc:0.8679, ave_prec:0.5772
# Train - precision:0.4476, recall:0.7833, Val - precision:0.3636, recall:0.5000
# Epoch: 036, Train loss: 0.73227, Val loss: 0.80903
# Train - roc_auc:0.8902, ave_prec:0.4388, Val - roc_auc:0.8679, ave_prec:0.5772
# Train - precision:0.4563, recall:0.7833, Val - precision:0.3636, recall:0.5000
# Epoch: 037, Train loss: 0.73881, Val loss: 0.80949
# Train - roc_auc:0.8916, ave_prec:0.4419, Val - roc_auc:0.8656, ave_prec:0.5748
# Train - precision:0.4476, recall:0.7833, Val - precision:0.3636, recall:0.5000
# Epoch: 038, Train loss: 0.72729, Val loss: 0.80906
# Train - roc_auc:0.8918, ave_prec:0.4422, Val - roc_auc:0.8656, ave_prec:0.5748
# Train - precision:0.4519, recall:0.7833, Val - precision:0.3636, recall:0.5000
# Epoch: 039, Train loss: 0.71813, Val loss: 0.80660
# Train - roc_auc:0.8933, ave_prec:0.4438, Val - roc_auc:0.8679, ave_prec:0.5769
# Train - precision:0.4563, recall:0.7833, Val - precision:0.3636, recall:0.5000
# Epoch: 040, Train loss: 0.72907, Val loss: 0.80034
# Train - roc_auc:0.8945, ave_prec:0.4477, Val - roc_auc:0.8679, ave_prec:0.5779
# Train - precision:0.4476, recall:0.7833, Val - precision:0.3636, recall:0.5000
# Epoch: 041, Train loss: 0.72195, Val loss: 0.79699
# Train - roc_auc:0.8947, ave_prec:0.4490, Val - roc_auc:0.8703, ave_prec:0.5793
# Train - precision:0.4519, recall:0.7833, Val - precision:0.3636, recall:0.5000
# Epoch: 042, Train loss: 0.70971, Val loss: 0.79294
# Train - roc_auc:0.8964, ave_prec:0.4506, Val - roc_auc:0.8726, ave_prec:0.5821
# Train - precision:0.4519, recall:0.7833, Val - precision:0.3636, recall:0.5000
# Epoch: 043, Train loss: 0.70554, Val loss: 0.79495
# Train - roc_auc:0.8974, ave_prec:0.4527, Val - roc_auc:0.8726, ave_prec:0.5821
# Train - precision:0.4615, recall:0.8000, Val - precision:0.3636, recall:0.5000
# Epoch: 044, Train loss: 0.70753, Val loss: 0.79805
# Train - roc_auc:0.8984, ave_prec:0.4535, Val - roc_auc:0.8703, ave_prec:0.5800
# Train - precision:0.4706, recall:0.8000, Val - precision:0.3636, recall:0.5000
# Epoch: 045, Train loss: 0.70434, Val loss: 0.79237
# Train - roc_auc:0.8995, ave_prec:0.4535, Val - roc_auc:0.8703, ave_prec:0.5800
# Train - precision:0.4712, recall:0.8167, Val - precision:0.3636, recall:0.5000
# Epoch: 046, Train loss: 0.69324, Val loss: 0.78748
# Train - roc_auc:0.8997, ave_prec:0.4580, Val - roc_auc:0.8726, ave_prec:0.5821
# Train - precision:0.4673, recall:0.8333, Val - precision:0.3636, recall:0.5000
# Epoch: 047, Train loss: 0.69803, Val loss: 0.78091
# Train - roc_auc:0.9003, ave_prec:0.4595, Val - roc_auc:0.8750, ave_prec:0.5852
# Train - precision:0.4717, recall:0.8333, Val - precision:0.3636, recall:0.5000
# Epoch: 048, Train loss: 0.69118, Val loss: 0.78159
# Train - roc_auc:0.9013, ave_prec:0.4595, Val - roc_auc:0.8750, ave_prec:0.5852
# Train - precision:0.4808, recall:0.8333, Val - precision:0.3636, recall:0.5000
# Epoch: 049, Train loss: 0.70337, Val loss: 0.77962
# Train - roc_auc:0.9024, ave_prec:0.4620, Val - roc_auc:0.8750, ave_prec:0.5852
# Train - precision:0.4851, recall:0.8167, Val - precision:0.3636, recall:0.5000
# Epoch: 050, Train loss: 0.69313, Val loss: 0.77438
# Train - roc_auc:0.9034, ave_prec:0.4656, Val - roc_auc:0.8774, ave_prec:0.5875
# Train - precision:0.4900, recall:0.8167, Val - precision:0.3636, recall:0.5000
# Epoch: 051, Train loss: 0.68147, Val loss: 0.77058
# Train - roc_auc:0.9041, ave_prec:0.4668, Val - roc_auc:0.8774, ave_prec:0.5875
# Train - precision:0.4900, recall:0.8167, Val - precision:0.3636, recall:0.5000
# Epoch: 052, Train loss: 0.68761, Val loss: 0.76521
# Train - roc_auc:0.9055, ave_prec:0.4721, Val - roc_auc:0.8797, ave_prec:0.5909
# Train - precision:0.4854, recall:0.8333, Val - precision:0.3636, recall:0.5000
# Epoch: 053, Train loss: 0.67116, Val loss: 0.76755
# Train - roc_auc:0.9064, ave_prec:0.4723, Val - roc_auc:0.8797, ave_prec:0.5909
# Train - precision:0.4900, recall:0.8167, Val - precision:0.3636, recall:0.5000
# Epoch: 054, Train loss: 0.67235, Val loss: 0.76628
# Train - roc_auc:0.9074, ave_prec:0.4798, Val - roc_auc:0.8774, ave_prec:0.5875
# Train - precision:0.5000, recall:0.8167, Val - precision:0.3636, recall:0.5000
# Epoch: 055, Train loss: 0.66683, Val loss: 0.75505
# Train - roc_auc:0.9082, ave_prec:0.4815, Val - roc_auc:0.8844, ave_prec:0.5975
# Train - precision:0.5000, recall:0.8167, Val - precision:0.4000, recall:0.5000
# Epoch: 056, Train loss: 0.65830, Val loss: 0.74718
# Train - roc_auc:0.9096, ave_prec:0.4849, Val - roc_auc:0.8892, ave_prec:0.6026
# Train - precision:0.5053, recall:0.8000, Val - precision:0.4000, recall:0.5000
# Epoch: 057, Train loss: 0.65623, Val loss: 0.74843
# Train - roc_auc:0.9099, ave_prec:0.4854, Val - roc_auc:0.8868, ave_prec:0.6000
# Train - precision:0.5000, recall:0.8167, Val - precision:0.4444, recall:0.5000
# Epoch: 058, Train loss: 0.65178, Val loss: 0.74906
# Train - roc_auc:0.9102, ave_prec:0.4870, Val - roc_auc:0.8892, ave_prec:0.6042
# Train - precision:0.4950, recall:0.8333, Val - precision:0.4444, recall:0.5000
# Epoch: 059, Train loss: 0.65800, Val loss: 0.74232
# Train - roc_auc:0.9109, ave_prec:0.4878, Val - roc_auc:0.8868, ave_prec:0.5933
# Train - precision:0.4904, recall:0.8500, Val - precision:0.3636, recall:0.5000
# Epoch: 060, Train loss: 0.64288, Val loss: 0.74508
# Train - roc_auc:0.9117, ave_prec:0.4919, Val - roc_auc:0.8868, ave_prec:0.5836
# Train - precision:0.4951, recall:0.8500, Val - precision:0.3636, recall:0.5000
# Epoch: 061, Train loss: 0.64414, Val loss: 0.74835
# Train - roc_auc:0.9127, ave_prec:0.4929, Val - roc_auc:0.8844, ave_prec:0.5808
# Train - precision:0.4951, recall:0.8500, Val - precision:0.4000, recall:0.5000
# Epoch: 062, Train loss: 0.64005, Val loss: 0.74870
# Train - roc_auc:0.9136, ave_prec:0.4959, Val - roc_auc:0.8844, ave_prec:0.5808
# Train - precision:0.4951, recall:0.8500, Val - precision:0.4000, recall:0.5000
# Epoch: 063, Train loss: 0.63643, Val loss: 0.74648
# Train - roc_auc:0.9138, ave_prec:0.4956, Val - roc_auc:0.8821, ave_prec:0.5767
# Train - precision:0.5000, recall:0.8667, Val - precision:0.3636, recall:0.5000
# Epoch: 064, Train loss: 0.63170, Val loss: 0.74200
# Train - roc_auc:0.9157, ave_prec:0.5004, Val - roc_auc:0.8868, ave_prec:0.5836
# Train - precision:0.5098, recall:0.8667, Val - precision:0.4444, recall:0.5000
# Epoch: 065, Train loss: 0.63111, Val loss: 0.74247
# Train - roc_auc:0.9171, ave_prec:0.5040, Val - roc_auc:0.8868, ave_prec:0.5836
# Train - precision:0.5258, recall:0.8500, Val - precision:0.4444, recall:0.5000
# Epoch: 066, Train loss: 0.62295, Val loss: 0.73801
# Train - roc_auc:0.9175, ave_prec:0.5050, Val - roc_auc:0.8868, ave_prec:0.5836
# Train - precision:0.5098, recall:0.8667, Val - precision:0.4444, recall:0.5000
# Epoch: 067, Train loss: 0.63298, Val loss: 0.73387
# Train - roc_auc:0.9182, ave_prec:0.5053, Val - roc_auc:0.8915, ave_prec:0.5941
# Train - precision:0.5098, recall:0.8667, Val - precision:0.5000, recall:0.6250
# Epoch: 068, Train loss: 0.61561, Val loss: 0.72737
# Train - roc_auc:0.9197, ave_prec:0.5068, Val - roc_auc:0.8986, ave_prec:0.6021
# Train - precision:0.5098, recall:0.8667, Val - precision:0.5000, recall:0.6250
# Epoch: 069, Train loss: 0.61811, Val loss: 0.72780
# Train - roc_auc:0.9204, ave_prec:0.5056, Val - roc_auc:0.8986, ave_prec:0.6021
# Train - precision:0.5098, recall:0.8667, Val - precision:0.4444, recall:0.5000
# Epoch: 070, Train loss: 0.61478, Val loss: 0.72980
# Train - roc_auc:0.9202, ave_prec:0.5045, Val - roc_auc:0.8939, ave_prec:0.5989
# Train - precision:0.5196, recall:0.8833, Val - precision:0.5000, recall:0.6250
# Epoch: 071, Train loss: 0.60907, Val loss: 0.72808
# Train - roc_auc:0.9215, ave_prec:0.5053, Val - roc_auc:0.8986, ave_prec:0.6061
# Train - precision:0.5354, recall:0.8833, Val - precision:0.4444, recall:0.5000
# Epoch: 072, Train loss: 0.60043, Val loss: 0.73356
# Train - roc_auc:0.9219, ave_prec:0.5084, Val - roc_auc:0.8986, ave_prec:0.6061
# Train - precision:0.5258, recall:0.8500, Val - precision:0.5000, recall:0.5000
# Epoch: 073, Train loss: 0.59566, Val loss: 0.72173
# Train - roc_auc:0.9222, ave_prec:0.5109, Val - roc_auc:0.8986, ave_prec:0.6061
# Train - precision:0.5243, recall:0.9000, Val - precision:0.5000, recall:0.6250
# Epoch: 074, Train loss: 0.59775, Val loss: 0.72341
# Train - roc_auc:0.9231, ave_prec:0.5109, Val - roc_auc:0.9009, ave_prec:0.6130
# Train - precision:0.5300, recall:0.8833, Val - precision:0.5556, recall:0.6250
# Epoch: 075, Train loss: 0.58950, Val loss: 0.71297
# Train - roc_auc:0.9243, ave_prec:0.5155, Val - roc_auc:0.9009, ave_prec:0.6130
# Train - precision:0.5243, recall:0.9000, Val - precision:0.5556, recall:0.6250
# Epoch: 076, Train loss: 0.58138, Val loss: 0.71072
# Train - roc_auc:0.9251, ave_prec:0.5169, Val - roc_auc:0.9033, ave_prec:0.6198
# Train - precision:0.5400, recall:0.9000, Val - precision:0.5556, recall:0.6250
# Epoch: 077, Train loss: 0.60004, Val loss: 0.71148
# Train - roc_auc:0.9255, ave_prec:0.5208, Val - roc_auc:0.9009, ave_prec:0.6130
# Train - precision:0.5347, recall:0.9000, Val - precision:0.5556, recall:0.6250
# Epoch: 078, Train loss: 0.58360, Val loss: 0.70911
# Train - roc_auc:0.9259, ave_prec:0.5207, Val - roc_auc:0.9009, ave_prec:0.6130
# Train - precision:0.5294, recall:0.9000, Val - precision:0.5556, recall:0.6250
# Epoch: 079, Train loss: 0.57329, Val loss: 0.71220
# Train - roc_auc:0.9261, ave_prec:0.5256, Val - roc_auc:0.8986, ave_prec:0.6115
# Train - precision:0.5243, recall:0.9000, Val - precision:0.5000, recall:0.6250
# Epoch: 080, Train loss: 0.57216, Val loss: 0.70689
# Train - roc_auc:0.9267, ave_prec:0.5254, Val - roc_auc:0.8986, ave_prec:0.6078
# Train - precision:0.5294, recall:0.9000, Val - precision:0.5000, recall:0.6250
# Epoch: 081, Train loss: 0.56346, Val loss: 0.70229
# Train - roc_auc:0.9281, ave_prec:0.5316, Val - roc_auc:0.9009, ave_prec:0.6130
# Train - precision:0.5294, recall:0.9000, Val - precision:0.5556, recall:0.6250
# Epoch: 082, Train loss: 0.56232, Val loss: 0.69845
# Train - roc_auc:0.9287, ave_prec:0.5307, Val - roc_auc:0.9009, ave_prec:0.6130
# Train - precision:0.5294, recall:0.9000, Val - precision:0.5000, recall:0.6250
# Epoch: 083, Train loss: 0.56631, Val loss: 0.69177
# Train - roc_auc:0.9298, ave_prec:0.5354, Val - roc_auc:0.9057, ave_prec:0.6234
# Train - precision:0.5347, recall:0.9000, Val - precision:0.5556, recall:0.6250
# Epoch: 084, Train loss: 0.57403, Val loss: 0.69902
# Train - roc_auc:0.9306, ave_prec:0.5387, Val - roc_auc:0.9080, ave_prec:0.6252
# Train - precision:0.5400, recall:0.9000, Val - precision:0.5556, recall:0.6250
# Epoch: 085, Train loss: 0.55493, Val loss: 0.69018
# Train - roc_auc:0.9310, ave_prec:0.5468, Val - roc_auc:0.9080, ave_prec:0.6227
# Train - precision:0.5347, recall:0.9000, Val - precision:0.5000, recall:0.6250
# Epoch: 086, Train loss: 0.55822, Val loss: 0.69140
# Train - roc_auc:0.9314, ave_prec:0.5534, Val - roc_auc:0.9033, ave_prec:0.6177
# Train - precision:0.5294, recall:0.9000, Val - precision:0.5000, recall:0.6250
# Epoch: 087, Train loss: 0.56256, Val loss: 0.68602
# Train - roc_auc:0.9320, ave_prec:0.5564, Val - roc_auc:0.9033, ave_prec:0.6177
# Train - precision:0.5294, recall:0.9000, Val - precision:0.5000, recall:0.6250
# Epoch: 088, Train loss: 0.54432, Val loss: 0.68256
# Train - roc_auc:0.9329, ave_prec:0.5479, Val - roc_auc:0.9080, ave_prec:0.6227
# Train - precision:0.5294, recall:0.9000, Val - precision:0.5000, recall:0.6250
# Epoch: 089, Train loss: 0.53905, Val loss: 0.68089
# Train - roc_auc:0.9334, ave_prec:0.5496, Val - roc_auc:0.9080, ave_prec:0.6215
# Train - precision:0.5347, recall:0.9000, Val - precision:0.5000, recall:0.6250
# Epoch: 090, Train loss: 0.53372, Val loss: 0.68292
# Train - roc_auc:0.9346, ave_prec:0.5568, Val - roc_auc:0.9104, ave_prec:0.6247
# Train - precision:0.5400, recall:0.9000, Val - precision:0.5000, recall:0.6250
# Epoch: 091, Train loss: 0.53866, Val loss: 0.67817
# Train - roc_auc:0.9350, ave_prec:0.5594, Val - roc_auc:0.9080, ave_prec:0.6227
# Train - precision:0.5294, recall:0.9000, Val - precision:0.5000, recall:0.6250
# Epoch: 092, Train loss: 0.52897, Val loss: 0.68396
# Train - roc_auc:0.9354, ave_prec:0.5594, Val - roc_auc:0.9080, ave_prec:0.6215
# Train - precision:0.5510, recall:0.9000, Val - precision:0.5000, recall:0.6250
# Epoch: 093, Train loss: 0.53313, Val loss: 0.68837
# Train - roc_auc:0.9362, ave_prec:0.5624, Val - roc_auc:0.9151, ave_prec:0.6317
# Train - precision:0.5567, recall:0.9000, Val - precision:0.5000, recall:0.6250
# Epoch: 094, Train loss: 0.52289, Val loss: 0.68788
# Train - roc_auc:0.9362, ave_prec:0.5622, Val - roc_auc:0.9127, ave_prec:0.6293
# Train - precision:0.5567, recall:0.9000, Val - precision:0.5000, recall:0.6250
# Epoch: 095, Train loss: 0.53192, Val loss: 0.67284
# Train - roc_auc:0.9372, ave_prec:0.5658, Val - roc_auc:0.9151, ave_prec:0.6257
# Train - precision:0.5400, recall:0.9000, Val - precision:0.5000, recall:0.6250
# Epoch: 096, Train loss: 0.51670, Val loss: 0.67685
# Train - roc_auc:0.9376, ave_prec:0.5685, Val - roc_auc:0.9127, ave_prec:0.6260
# Train - precision:0.5347, recall:0.9000, Val - precision:0.5000, recall:0.6250
# Epoch: 097, Train loss: 0.52092, Val loss: 0.66585
# Train - roc_auc:0.9388, ave_prec:0.5684, Val - roc_auc:0.9127, ave_prec:0.6260
# Train - precision:0.5294, recall:0.9000, Val - precision:0.5000, recall:0.6250
# Epoch: 098, Train loss: 0.51348, Val loss: 0.67241
# Train - roc_auc:0.9395, ave_prec:0.5726, Val - roc_auc:0.9198, ave_prec:0.6376
# Train - precision:0.5455, recall:0.9000, Val - precision:0.5000, recall:0.6250
# Epoch: 099, Train loss: 0.50721, Val loss: 0.66902
# Train - roc_auc:0.9392, ave_prec:0.5708, Val - roc_auc:0.9198, ave_prec:0.6373
# Train - precision:0.5455, recall:0.9000, Val - precision:0.5000, recall:0.6250
# Epoch: 100, Train loss: 0.49890, Val loss: 0.65643
# Train - roc_auc:0.9402, ave_prec:0.5738, Val - roc_auc:0.9222, ave_prec:0.6405
# Train - precision:0.5400, recall:0.9000, Val - precision:0.5000, recall:0.6250
# Epoch: 101, Train loss: 0.49840, Val loss: 0.65131
# Train - roc_auc:0.9407, ave_prec:0.5755, Val - roc_auc:0.9198, ave_prec:0.6318
# Train - precision:0.5455, recall:0.9000, Val - precision:0.5000, recall:0.6250
# Epoch: 102, Train loss: 0.49316, Val loss: 0.66756
# Train - roc_auc:0.9421, ave_prec:0.5807, Val - roc_auc:0.9198, ave_prec:0.6318
# Train - precision:0.5521, recall:0.8833, Val - precision:0.5000, recall:0.6250
# Epoch: 103, Train loss: 0.49355, Val loss: 0.65911
# Train - roc_auc:0.9423, ave_prec:0.5816, Val - roc_auc:0.9222, ave_prec:0.6354
# Train - precision:0.5510, recall:0.9000, Val - precision:0.5000, recall:0.6250
# Epoch: 104, Train loss: 0.48662, Val loss: 0.64703
# Train - roc_auc:0.9438, ave_prec:0.5866, Val - roc_auc:0.9198, ave_prec:0.6298
# Train - precision:0.5510, recall:0.9000, Val - precision:0.5000, recall:0.6250
# Epoch: 105, Train loss: 0.48516, Val loss: 0.64725
# Train - roc_auc:0.9444, ave_prec:0.5999, Val - roc_auc:0.9175, ave_prec:0.6228
# Train - precision:0.5455, recall:0.9000, Val - precision:0.5000, recall:0.6250
# Epoch: 106, Train loss: 0.48205, Val loss: 0.64515
# Train - roc_auc:0.9449, ave_prec:0.5936, Val - roc_auc:0.9245, ave_prec:0.6375
# Train - precision:0.5567, recall:0.9000, Val - precision:0.5000, recall:0.6250
# Epoch: 107, Train loss: 0.47407, Val loss: 0.65091
# Train - roc_auc:0.9455, ave_prec:0.5981, Val - roc_auc:0.9198, ave_prec:0.6270
# Train - precision:0.5567, recall:0.9000, Val - precision:0.5000, recall:0.6250
# Epoch: 108, Train loss: 0.46375, Val loss: 0.64290
# Train - roc_auc:0.9464, ave_prec:0.6002, Val - roc_auc:0.9245, ave_prec:0.6375
# Train - precision:0.5567, recall:0.9000, Val - precision:0.5000, recall:0.6250
# Epoch: 109, Train loss: 0.46516, Val loss: 0.64194
# Train - roc_auc:0.9464, ave_prec:0.6010, Val - roc_auc:0.9245, ave_prec:0.6375
# Train - precision:0.5567, recall:0.9000, Val - precision:0.5000, recall:0.6250
# Epoch: 110, Train loss: 0.47517, Val loss: 0.62831
# Train - roc_auc:0.9471, ave_prec:0.6030, Val - roc_auc:0.9222, ave_prec:0.6345
# Train - precision:0.5392, recall:0.9167, Val - precision:0.5000, recall:0.6250
# Epoch: 111, Train loss: 0.46334, Val loss: 0.63373
# Train - roc_auc:0.9472, ave_prec:0.6043, Val - roc_auc:0.9245, ave_prec:0.6375
# Train - precision:0.5567, recall:0.9000, Val - precision:0.5000, recall:0.6250
# Epoch: 112, Train loss: 0.46414, Val loss: 0.62670
# Train - roc_auc:0.9480, ave_prec:0.6078, Val - roc_auc:0.9269, ave_prec:0.6407
# Train - precision:0.5567, recall:0.9000, Val - precision:0.5000, recall:0.6250
# Epoch: 113, Train loss: 0.45523, Val loss: 0.63200
# Train - roc_auc:0.9484, ave_prec:0.6103, Val - roc_auc:0.9245, ave_prec:0.6375
# Train - precision:0.5625, recall:0.9000, Val - precision:0.5000, recall:0.6250
# Epoch: 114, Train loss: 0.46012, Val loss: 0.63935
# Train - roc_auc:0.9498, ave_prec:0.6147, Val - roc_auc:0.9222, ave_prec:0.6345
# Train - precision:0.5510, recall:0.9000, Val - precision:0.5000, recall:0.6250
# Epoch: 115, Train loss: 0.45105, Val loss: 0.64119
# Train - roc_auc:0.9507, ave_prec:0.6148, Val - roc_auc:0.9245, ave_prec:0.6375
# Train - precision:0.5625, recall:0.9000, Val - precision:0.4444, recall:0.5000
# Epoch: 116, Train loss: 0.44107, Val loss: 0.65461
# Train - roc_auc:0.9513, ave_prec:0.6160, Val - roc_auc:0.9245, ave_prec:0.6375
# Train - precision:0.5579, recall:0.8833, Val - precision:0.5000, recall:0.5000
# Epoch: 117, Train loss: 0.45527, Val loss: 0.63063
# Train - roc_auc:0.9519, ave_prec:0.6224, Val - roc_auc:0.9269, ave_prec:0.6407
# Train - precision:0.5625, recall:0.9000, Val - precision:0.4444, recall:0.5000
# Epoch: 118, Train loss: 0.43523, Val loss: 0.62586
# Train - roc_auc:0.9521, ave_prec:0.6239, Val - roc_auc:0.9245, ave_prec:0.6375
# Train - precision:0.5567, recall:0.9000, Val - precision:0.4444, recall:0.5000
# Epoch: 119, Train loss: 0.42843, Val loss: 0.62720
# Train - roc_auc:0.9527, ave_prec:0.6258, Val - roc_auc:0.9245, ave_prec:0.6375
# Train - precision:0.5625, recall:0.9000, Val - precision:0.5000, recall:0.5000
# Epoch: 120, Train loss: 0.42739, Val loss: 0.61651
# Train - roc_auc:0.9533, ave_prec:0.6369, Val - roc_auc:0.9245, ave_prec:0.6375
# Train - precision:0.5567, recall:0.9000, Val - precision:0.5000, recall:0.5000
# Epoch: 121, Train loss: 0.42517, Val loss: 0.61103
# Train - roc_auc:0.9538, ave_prec:0.6387, Val - roc_auc:0.9269, ave_prec:0.6407
# Train - precision:0.5567, recall:0.9000, Val - precision:0.4444, recall:0.5000
# Epoch: 122, Train loss: 0.41940, Val loss: 0.60249
# Train - roc_auc:0.9542, ave_prec:0.6483, Val - roc_auc:0.9292, ave_prec:0.6444
# Train - precision:0.5670, recall:0.9167, Val - precision:0.4444, recall:0.5000
# Epoch: 123, Train loss: 0.41912, Val loss: 0.60184
# Train - roc_auc:0.9551, ave_prec:0.6547, Val - roc_auc:0.9316, ave_prec:0.6569
# Train - precision:0.5500, recall:0.9167, Val - precision:0.4444, recall:0.5000
# Epoch: 124, Train loss: 0.41972, Val loss: 0.60555
# Train - roc_auc:0.9552, ave_prec:0.6348, Val - roc_auc:0.9292, ave_prec:0.6444
# Train - precision:0.5556, recall:0.9167, Val - precision:0.4444, recall:0.5000
# Epoch: 125, Train loss: 0.40580, Val loss: 0.61111
# Train - roc_auc:0.9558, ave_prec:0.6373, Val - roc_auc:0.9292, ave_prec:0.6444
# Train - precision:0.5745, recall:0.9000, Val - precision:0.5714, recall:0.5000
# Test loss: 0.65339
# Test - roc_auc:0.9222, ave_prec:0.7121
# Test - precision:0.5556, recall:0.6250

# %%
tr_precision, tr_recall = test_precision_recall(model, train_loader, pred_th=0.8)
val_precision, val_recall  = test_precision_recall(model, val_loader, pred_th=0.8)
print('Train - precision:{:.4f}, recall:{:.4f}, Val - precision:{:.4f}, recall:{:.4f}'.format(
    tr_precision, tr_recall, val_precision, val_recall))
te_precision, te_recall = test_precision_recall(model, test_loader, pred_th=0.8)
print('Test - precision:{:.4f}, recall:{:.4f}'.format(te_precision, te_recall))
# Out:
# Train - precision:0.6000, recall:0.8500, Val - precision:0.5714, recall:0.5000
# Test - precision:0.6250, recall:0.6250

# %%
#torch.save(model, 'trained_models/AFP_tl_cisplatin_0.85093')
torch.save(model, 'trained_models/AFP_tl_cisplatin_test')

# %%
model = torch.load('trained_models/AFP_tl_cisplatin_0.85093')
te_score = test(model, test_loader)
print('Test: {:.5f}'.format(te_score))
